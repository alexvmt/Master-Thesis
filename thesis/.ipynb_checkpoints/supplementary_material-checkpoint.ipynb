# %% [markdown]
# #### Supplementary Material for Master Thesis on
# # Evaluation of Machine Learning and Deep Learning Models for Customer Journey Prediction in E-Commerce - An Executive Perspective
# #### Supervisor: Prof. Dr. Jörn Grahl
# #### Author: Alexander Merdian-Tarko

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# set options for pandas and matplotlib
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 500)
pd.options.display.max_colwidth = 200
pd.options.display.float_format = '{:20,.4f}'.format
plt.rcParams['font.family'] = 'Times New Roman'
# %matplotlib inline

# %% [markdown]
# ## 3. Related Work

# %% [markdown]
# ### 3.1. General Comparative Studies

# %%
# overview of general comparative studies (Table 1)
general_literature = pd.read_csv('table_1_thesis_general_literature.csv', sep=';').set_index('Studies')
general_literature
# Out:
#                                                                                                                     Models  \
# Studies
# Weiss and Kapouleas (1989)                                                                     DA, KNN, BM, NN, RL, DT (9)
# Shavlik et al. (1991)                                                                                           DT, NN (3)
# Michie et al. (1994)                                                                  DA, DT, RL, LR, KNN, BM, NB, NN (23)
# King et al. (1995)                                                            DT, RL, NB, KNN, DA, LR, BM, NN, MISC-M (17)
# Bradley (1997)                                                                                         DT, NN, KNN, DA (9)
# Bauer and Kohavi (1999)                                                                             DT, NB, BAG, BOOST (7)
# Lim et al. (2000)                                                                                  DT, RL, DA, LR, NN (33)
# Huang et al. (2003)                                                                                        NB, DT, SVM (4)
# Perlich et al. (2003)                                                                                      DT, LR, BAG (8)
# Provost and Domingos (2003)                                                                                    DT, BAG (5)
# Tan and Gilbert (2003)                                                      DT, RL, NB, KNN, SVM, NN, STC, BAG, BOOST (17)
# Caruana and Niculesci-Mizil (2006)                                           SVM, NN, LR, NB, KNN, RF, DT, BAG, BOOST (30)
# Fernandez-Delgado et al. (2014)     DA, NB, BM, NN, SVM, DT, RL, BOOST, BAG, STC, RF, ENS, GLM, KNN, LR, REG, MISC-M (179)
# Khan et al. (2018)                                                                                 KNN, SVM, ENN, LMNN (4)
# Olson et al. (2018)                                                           NB, LR, SVM, KNN, DT, RF, BOOST, MISC-M (13)
#
#                                     Data sets  \
# Studies
# Weiss and Kapouleas (1989)                  4
# Shavlik et al. (1991)                       5
# Michie et al. (1994)                       22
# King et al. (1995)                         12
# Bradley (1997)                              6
# Bauer and Kohavi (1999)                    14
# Lim et al. (2000)                          32
# Huang et al. (2003)                        18
# Perlich et al. (2003)                      36
# Provost and Domingos (2003)                25
# Tan and Gilbert (2003)                      4
# Caruana and Niculesci-Mizil (2006)         11
# Fernandez-Delgado et al. (2014)           121
# Khan et al. (2018)                         11
# Olson et al. (2018)                       165
#
#                                                                        Instances  \
# Studies
# Weiss and Kapouleas (1989)                                              106-3772
# Shavlik et al. (1991)                                                  226-11500
# Michie et al. (1994)                                                   270-58000
# King et al. (1995)                                                     270-58000
# Bradley (1997)                                                           117-768
# Bauer and Kohavi (1999)                                               1000-58000
# Lim et al. (2000)                                                       151-4435
# Huang et al. (2003)                                                     132-8124
# Perlich et al. (2003)                                               700-1000000+
# Provost and Domingos (2003)              unclear, but incl. large-scale datasets
# Tan and Gilbert (2003)                                                  106-1484
# Caruana and Niculesci-Mizil (2006)                                    9366-40222
# Fernandez-Delgado et al. (2014)                                        10-130064
# Khan et al. (2018)                                                 ~200 to ~5000
# Olson et al. (2018)                 mostly < 5000 and incl. large-scale datasets
#
#                                    Types Classes  \
# Studies
# Weiss and Kapouleas (1989)             R     B/M
# Shavlik et al. (1991)                  R     B/M
# Michie et al. (1994)                 R/S     B/M
# King et al. (1995)                     R     B/M
# Bradley (1997)                         R       B
# Bauer and Kohavi (1999)                R     B/M
# Lim et al. (2000)                    R/S     B/M
# Huang et al. (2003)                    R     B/M
# Perlich et al. (2003)                  R       B
# Provost and Domingos (2003)            R     B/M
# Tan and Gilbert (2003)                 R     B/M
# Caruana and Niculesci-Mizil (2006)     R       B
# Fernandez-Delgado et al. (2014)        R     B/M
# Khan et al. (2018)                     R     B/M
# Olson et al. (2018)                    R     B/M
#
#                                                                                 Evaluation metrics
# Studies
# Weiss and Kapouleas (1989)                                                                Accuracy
# Shavlik et al. (1991)                                                               Accuracy, time
# Michie et al. (1994)                Time, accuracy, ranking, cost, complexity, qualitative, MISC-E
# King et al. (1995)                                               Accuracy, cost, time, qualitative
# Bradley (1997)                                                                     Accuracy, tests
# Bauer and Kohavi (1999)                                                                   Accuracy
# Lim et al. (2000)                                                       Accuracy, time, complexity
# Huang et al. (2003)                                                                       Accuracy
# Perlich et al. (2003)                                                            Accuracy, ranking
# Provost and Domingos (2003)                                                      Ranking, accuracy
# Tan and Gilbert (2003)                                                                    Accuracy
# Caruana and Niculesci-Mizil (2006)                                                Accuracy, MISC-E
# Fernandez-Delgado et al. (2014)                                Rankinging, accuracy, tests, MISC-E
# Khan et al. (2018)                                                                        Accuracy
# Olson et al. (2018)                                                       Ranking, accuracy, tests

# %% [markdown]
# ### 3.2. Comparative Studies Focused on Customer Journey Prediction

# %%
# overview of comparative studies focused on customer journey prediction (Table 2)
marketing_literature = pd.read_csv('table_2_thesis_marketing_literature.csv', sep=';').set_index('Studies')
marketing_literature
# Out:
#                                                         Models  \
# Studies
# Moe and Fader (2004)                          CM, LR, MISC (6)
# Suh et al. (2004)                          DT, NN, LR, ENS (4)
# Boroujerdi et al. (2014)     DT, RF, LR, NN, SVM, RL, KNN (16)
# Sarwar et al. (2015)                 NB, RF, BM, LR, BOOST (5)
# Vieira (2015)                             LR, RF, DBN, SDA (5)
# Wu et al. (2015)                            RNN, NN, BOOST (3)
# Lang and Rettenmeier (2017)                    LR, NN, RNN (3)
# Toth et al. (2017)                                 MM, RNN (2)
# Sakar et al. (2018)                        DT, RF, SVM, NN (4)
# Sheil et al. (2018)                             RNN, BOOST (4)
#
#                                                                                        Data  \
# Studies
# Moe and Fader (2004)                                                        11.000 sessions
# Suh et al. (2004)                                                             73.000 events
# Boroujerdi et al. (2014)                                                    60.000 sessions
# Sarwar et al. (2015)                                                    11.800.000 sessions
# Vieira (2015)                                                            1.000.000 sessions
# Wu et al. (2015)                                                        11.800.000 sessions
# Lang and Rettenmeier (2017)                                        several million sessions
# Toth et al. (2017)                                                         199.000 sessions
# Sakar et al. (2018)                                                         12.000 sessions
# Sheil et al. (2018)          9.200.000 sessions (dataset 1), 1.400.000 sessions (dataset 2)
#
#                                                                        Targets  \
# Studies
# Moe and Fader (2004)                           Purchase probability of session
# Suh et al. (2004)                              Purchase probability of session
# Boroujerdi et al. (2014)                       Purchase probability of session
# Sarwar et al. (2015)           Purchase or no purchase session and item bought
# Vieira (2015)                 Purchase within next 24 hours of current session
# Wu et al. (2015)               Purchase or no purchase session and item bought
# Lang and Rettenmeier (2017)     Purchase within next 7 days of current session
# Toth et al. (2017)           Purchase, abandoned cart or browsing-only session
# Sakar et al. (2018)                            Purchase or no purchase session
# Sheil et al. (2018)                            Purchase or no purchase session
#
#                                                                                     Evaluation metrics
# Studies
# Moe and Fader (2004)         Log-likelihood, Bayesian information criterion, predicted conversion rate
# Suh et al. (2004)                                              Accuracy, misclassification error, lift
# Boroujerdi et al. (2014)                                                    Precision, recall, F-score
# Sarwar et al. (2015)         Custom score from RecSys 2015 Challenge, precision, recall, training time
# Vieira (2015)                                                                                      AUC
# Wu et al. (2015)                                               Custom score from RecSys 2015 Challenge
# Lang and Rettenmeier (2017)                                               Negative log-likelihood, AUC
# Toth et al. (2017)                                                          Precision, recall, F-score
# Sakar et al. (2018)           ACC, F-score, true-positive/true-negative rate, statistical significance
# Sheil et al. (2018)                                                                           AUC, ROC

# %% [markdown]
# ## 5. Experiments

# %% [markdown]
# ### 5.2. Data

# %% [markdown]
# #### Descriptive statistics for cleaning and mapping stage

# %%
# load descriptive statistics for cleaning and mapping stage
cm5 = pd.read_pickle('../results/descriptives/cleaning_and_mapping_descriptives_clickstream_0516.pkl.gz')
cm6 = pd.read_pickle('../results/descriptives/cleaning_and_mapping_descriptives_clickstream_0616.pkl.gz')
cm7 = pd.read_pickle('../results/descriptives/cleaning_and_mapping_descriptives_clickstream_0716.pkl.gz')
cm8 = pd.read_pickle('../results/descriptives/cleaning_and_mapping_descriptives_clickstream_0816.pkl.gz')
cm9 = pd.read_pickle('../results/descriptives/cleaning_and_mapping_descriptives_clickstream_0916.pkl.gz')
cm10 = pd.read_pickle('../results/descriptives/cleaning_and_mapping_descriptives_clickstream_1016.pkl.gz')

# create dataframe with all descriptive statistics for all months
cm = cm5
for df in [cm6, 
          cm7, 
          cm8, 
          cm9, 
          cm10]:
    cm = cm.append(df)
    
cm
# Out:
#                   rows_pre  rows_post  columns_pre  columns_post  \
# clickstream_0516   5817272    5797325           42            48
# clickstream_0616   4034158    3996690           42            48
# clickstream_0716   3351498    3278976           42            48
# clickstream_0816   4076656    3941320           42            48
# clickstream_0916   5540730    5336437           42            48
# clickstream_1016   6675456    6599686           42            48
#
#                   unique_visitors_pre  unique_visitors_post  run_time
# clickstream_0516               938197                938088      1572
# clickstream_0616               732788                732521      1078
# clickstream_0716               631934                631412       803
# clickstream_0816               860803                774499       943
# clickstream_0916              1098921                933425      1283
# clickstream_1016              1132710               1117834      1563

# %%
# calculate percentage difference of rows for each month
cm['diff (%)'] = (cm['rows_pre']-cm['rows_post'])/cm['rows_pre']*100
cm
# Out:
#                   rows_pre  rows_post  columns_pre  columns_post  \
# clickstream_0516   5817272    5797325           42            48
# clickstream_0616   4034158    3996690           42            48
# clickstream_0716   3351498    3278976           42            48
# clickstream_0816   4076656    3941320           42            48
# clickstream_0916   5540730    5336437           42            48
# clickstream_1016   6675456    6599686           42            48
#
#                   unique_visitors_pre  unique_visitors_post  run_time  \
# clickstream_0516               938197                938088      1572
# clickstream_0616               732788                732521      1078
# clickstream_0716               631934                631412       803
# clickstream_0816               860803                774499       943
# clickstream_0916              1098921                933425      1283
# clickstream_1016              1132710               1117834      1563
#
#                              diff (%)
# clickstream_0516               0.3429
# clickstream_0616               0.9288
# clickstream_0716               2.1639
# clickstream_0816               3.3198
# clickstream_0916               3.6871
# clickstream_1016               1.1351

# %%
# calculate total percentage of rows removed in cleaning and mapping stage
print(round((cm['rows_pre'].sum()-cm['rows_post'].sum())/cm['rows_pre'].sum()*100, 2), '%')
# Out:
# 1.85 %

# %% [markdown]
# #### Descriptive statistics of data processing stages

# %%
# rows, columns and unique visitors after every stage of processing the data (Table 3)
stage_descriptives = pd.read_pickle('../results/descriptives/stage_descriptives.pkl.gz')
stage_descriptives
# Out:
#                                      Rows Columns Unique visitors
# Raw                              29495770      42         4717042
# Cleaning and mapping             28950434      48         4450709
# Aggregation                       6552128      50         4450709
# Preparing target and features     3296711     169         2453298
# Feature selection/preprocessing   3296711     137         2453298

# %% [markdown]
# ### 5.3. Descriptive Statistics

# %% [markdown]
# #### Descriptive statistics of all data samples

# %%
# descriptive statistics for all 10 data samples and the full sample (Table 4)
sample_descriptives = pd.read_pickle('../results/descriptives/sample_descriptives.pkl.gz')
sample_descriptives
# Out:
#             Unique visitors Sessions Visitors with >= 2 sessions  \
# Sample 1               3906     5591                         698
# Sample 2               7812    10736                        1430
# Sample 3              15625    21480                        2839
# Sample 4              31250    42836                        5695
# Sample 5              62500    84757                       11502
# Sample 6             125000   168202                       22860
# Sample 7             250000   336018                       45602
# Sample 8             500000   671664                       91292
# Sample 9            1000000  1342635                      183532
# Sample 10           2000000  2687600                      367095
# Full sample         2453174  3296576                      449864
#
#             Visitors with >= 5 sessions      Mean # sessions  \
# Sample 1                             65               1.4314
# Sample 2                            117               1.3743
# Sample 3                            258               1.3747
# Sample 4                            541               1.3708
# Sample 5                           1057               1.3561
# Sample 6                           2098               1.3456
# Sample 7                           4145               1.3441
# Sample 8                           8245               1.3433
# Sample 9                          16389               1.3426
# Sample 10                         32780               1.3438
# Full sample                       40209               1.3438
#
#                Median # sessions Standard deviation # sessions Buyers  \
# Sample 1                  1.0000                        3.7541    131
# Sample 2                  1.0000                        2.7333    260
# Sample 3                  1.0000                        3.0801    523
# Sample 4                  1.0000                        2.6352   1054
# Sample 5                  1.0000                        2.0870   2079
# Sample 6                  1.0000                        1.8120   4274
# Sample 7                  1.0000                        1.9582   8466
# Sample 8                  1.0000                        1.8721  17110
# Sample 9                  1.0000                        2.1338  34582
# Sample 10                 1.0000                        2.0465  68985
# Full sample               1.0000                        2.0526  84510
#
#             Conversions      Conversion rate
# Sample 1            161               0.0288
# Sample 2            319               0.0297
# Sample 3            642               0.0299
# Sample 4           1301               0.0304
# Sample 5           2566               0.0303
# Sample 6           5247               0.0312
# Sample 7          10443               0.0311
# Sample 8          21238               0.0316
# Sample 9          42906               0.0320
# Sample 10         85619               0.0319
# Full sample      104831               0.0318

# %% [markdown]
# #### Plot of visits, purchases, page views and product views per week

# %%
# load data to generate plot
plot_data = pd.read_pickle('../data/processed_data/clickstream_0516-1016_prepared.pkl.gz')

# %%
# create week column
plot_data['week'] = plot_data['visit_start_time_gmt'].apply(lambda x: x.isocalendar()[1])

# calculate visits per week
visits_per_week = plot_data.groupby('week').size().reset_index(name='visits')

# calculate purchases within next 24 hours per week
purchases_within_next_24_hours_per_week = plot_data[plot_data['purchase_within_next_24_hours'] == 1].groupby('week').size().reset_index(name='purchases_24_hours')

# calculate page views per week
page_views_per_week = plot_data.groupby('week', as_index=False).agg({'page_view_boolean_sum' : 'sum'})

# calculate product views per week
product_views_per_week = plot_data.groupby('week', as_index=False).agg({'product_view_boolean_sum' : 'sum'})

# %%
# Figure 1
plt.figure(figsize=(12,8))

# visits per week
plt.subplot(2,2,1)
plt.plot(visits_per_week.week, visits_per_week.visits/1000, linewidth=2, marker='X', markersize=8)
plt.title('Visits', fontsize=16)
plt.ylabel('Number\n(thousands)', fontsize=16)
#plt.xlabel('Week', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.grid(True)

# purchases per week
plt.subplot(2,2,2)
plt.plot(purchases_within_next_24_hours_per_week.week, purchases_within_next_24_hours_per_week.purchases_24_hours/1000, linewidth=2, marker='X', markersize=8)
plt.title('Purchases', fontsize=16)
#plt.ylabel('Number\n(thousands)', fontsize=16)
#plt.xlabel('Week', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.grid(True)

# page views per week
plt.subplot(2,2,3)
plt.plot(page_views_per_week.week, page_views_per_week.page_view_boolean_sum/1000, linewidth=2, marker='X', markersize=8)
plt.title('Page views', fontsize=16)
plt.ylabel('Number\n(thousands)', fontsize=16)
plt.xlabel('Week', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.grid(True)

# product views per week
plt.subplot(2,2,4)
plt.plot(product_views_per_week.week, product_views_per_week.product_view_boolean_sum/1000, linewidth=2, marker='X', markersize=8)
plt.title('Product views', fontsize=16)
#plt.ylabel('Number\n(thousands)', fontsize=16)
plt.xlabel('Week', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.grid(True)

plt.tight_layout()
plt.savefig('visits_purchases_page_views_product_views_per_week.png')
plt.show()

# %% [markdown]
# ## 6. Evaluation of Models and Experimental Results

# %% [markdown]
# ### 6.1. Objectivity

# %%
# load coefficients and feature importances
coef_lr = pd.read_pickle('../results/model_performance/coefficients_1600000_LR.pkl.gz')
coef_svm = pd.read_pickle('../results/model_performance/coefficients_1600000_SVM.pkl.gz')
feat_imp_dt = pd.read_pickle('../results/model_performance/feature_importances_1600000_DT.pkl.gz')
feat_imp_rf = pd.read_pickle('../results/model_performance/feature_importances_1600000_RF.pkl.gz')
feat_imp_boost = pd.read_pickle('../results/model_performance/feature_importances_1600000_BOOST.pkl.gz')

# %%
# LR top 10 features
coef_lr['abs'] = abs(coef_lr['Coefficients'])
coef_lr.sort_values('abs', ascending=False).head(10)[['Features', 'Coefficients']]
# Out:
#                                      Features         Coefficients
# 130                 purchase_in_last_24_hours              -4.4730
# 133             purchase_in_last_30_plus_days              -3.4944
# 131                   purchase_in_last_7_days              -3.2762
# 132                  purchase_in_last_30_days              -3.1003
# 53                   user_gender_first_female               2.7581
# 54                     user_gender_first_male               2.6112
# 23                        repeat_orders_first               2.3587
# 61   product_categories_first_level_1_Unknown              -1.7776
# 99                       user_age_56-65_first               1.7141
# 97                       user_age_36-45_first               1.7120

# %%
# SVM top 10 features
coef_svm['abs'] = abs(coef_svm['Coefficients'])
coef_svm.sort_values('abs', ascending=False).head(10)[['Features', 'Coefficients']]
# Out:
#                           Features         Coefficients
# 23             repeat_orders_first               1.4314
# 130      purchase_in_last_24_hours              -1.4154
# 133  purchase_in_last_30_plus_days              -1.2520
# 131        purchase_in_last_7_days              -1.1850
# 132       purchase_in_last_30_days              -1.1666
# 53        user_gender_first_female               0.5846
# 54          user_gender_first_male               0.5341
# 15         persistent_cookie_first               0.4599
# 99            user_age_56-65_first               0.4429
# 100         user_age_65_plus_first               0.4327

# %%
# DT top 10 features
feat_imp_dt.sort_values('Feature importances', ascending=False).head(10)
# Out:
#                      Features  Feature importances
# 5       cart_view_boolean_sum               0.4074
# 8       last_purchase_num_max               0.1558
# 10     product_item_price_sum               0.0470
# 54     user_gender_first_male               0.0424
# 53   user_gender_first_female               0.0375
# 102    visit_duration_seconds               0.0356
# 9           product_items_sum               0.0268
# 1          visit_page_num_max               0.0246
# 7       page_view_boolean_sum               0.0180
# 2    product_view_boolean_sum               0.0145

# %%
# RF top 10 features
feat_imp_rf.sort_values('Feature importances', ascending=False).head(10)
# Out:
#                              Features  Feature importances
# 5               cart_view_boolean_sum               0.1105
# 53           user_gender_first_female               0.0873
# 54             user_gender_first_male               0.0729
# 8               last_purchase_num_max               0.0685
# 3           cart_addition_boolean_sum               0.0536
# 9                   product_items_sum               0.0432
# 7               page_view_boolean_sum               0.0392
# 52   net_promoter_score_first_Unknown               0.0372
# 10             product_item_price_sum               0.0372
# 102            visit_duration_seconds               0.0357

# %%
# BOOST top 10 features
feat_imp_boost.sort_values('Feature importances', ascending=False).head(10)
# Out:
#                                            Features  Feature importances
# 5                             cart_view_boolean_sum               0.6279
# 8                             last_purchase_num_max               0.1582
# 54                           user_gender_first_male               0.0418
# 53                         user_gender_first_female               0.0411
# 7                             page_view_boolean_sum               0.0319
# 0                                         visit_num               0.0164
# 10                           product_item_price_sum               0.0138
# 9                                 product_items_sum               0.0115
# 69  device_type_user_agent_first_reduced_smartphone               0.0080
# 97                             user_age_36-45_first               0.0072

# %% [markdown]
# ### 6.2. Predictive Accuracy

# %% [markdown]
# #### Sample 1 (3906 unique visitors)

# %%
# load performance metrics
lr_4k = pd.read_pickle('../results/model_performance/model_performance_3125_LR.pkl.gz')
dt_4k = pd.read_pickle('../results/model_performance/model_performance_3125_DT.pkl.gz')
nb_4k = pd.read_pickle('../results/model_performance/model_performance_3125_NB.pkl.gz')
knn_4k = pd.read_pickle('../results/model_performance/model_performance_3125_KNN.pkl.gz')
rf_4k = pd.read_pickle('../results/model_performance/model_performance_3125_RF.pkl.gz')
svm_4k = pd.read_pickle('../results/model_performance/model_performance_3125_SVM.pkl.gz')
boost_4k = pd.read_pickle('../results/model_performance/model_performance_3125_BOOST.pkl.gz')
nn1_4k = pd.read_pickle('../results/model_performance/model_performance_3125_NN1.pkl.gz')
nn3_4k = pd.read_pickle('../results/model_performance/model_performance_3125_NN3.pkl.gz')
nn5_4k = pd.read_pickle('../results/model_performance/model_performance_3125_NN5.pkl.gz')
rnn_4k = pd.read_pickle('../results/model_performance/model_performance_3125_RNN.pkl.gz')
lstm_4k = pd.read_pickle('../results/model_performance/model_performance_3125_LSTM.pkl.gz')

# create dataframe with all models
model_performance_4k = lr_4k
for df in [dt_4k, 
           nb_4k, 
           knn_4k, 
           rf_4k, 
           svm_4k, 
           boost_4k, 
           nn1_4k, 
           nn3_4k, 
           nn5_4k, 
           rnn_4k, 
           lstm_4k]:
    model_performance_4k = model_performance_4k.append(df)

model_performance_4k
# Out:
#        Unique visitors train  Unique visitors test  Sessions train  \
# LR                      3125                   781            4480
# DT                      3125                   781            4480
# NB                      3125                   781            4480
# KNN                     3125                   781            4480
# RF                      3125                   781            4480
# SVM                     3125                   781            4480
# BOOST                   3125                   781            4480
# NN1                     3125                   781            4480
# NN3                     3125                   781            4480
# NN5                     3125                   781            4480
# RNN                     3125                   781            4480
# LSTM                    3125                   781            4480
#
#        Sessions test  Features  Training time  Testing time  \
# LR              1111       134              0             0
# DT              1111       134              0             0
# NB              1111       134              0             0
# KNN             1111       134              0             1
# RF              1111       134              0             0
# SVM             1111       134              0             0
# BOOST           1111       134              1             0
# NN1             1111       134              1             0
# NN3             1111       134              2             0
# NN5             1111       134              3             0
# RNN             1111       115             23             1
# LSTM            1111       115             73             1
#
#                   Accuracy                  AUC  True negatives  \
# LR                  0.9820               0.8149            1075
# DT                  0.9766               0.8513            1067
# NB                  0.2079               0.5362             209
# KNN                 0.9694               0.5936            1072
# RF                  0.9829               0.8154            1076
# SVM                 0.9739               0.8694            1063
# BOOST               0.9784               0.9303            1065
# NN1                 0.9766               0.8317            1068
# NN3                 0.9757               0.7922            1069
# NN5                 0.9721               0.8099            1064
# RNN                 0.9775               0.6172            1080
# LSTM                0.9784               0.6372            1080
#
#        False negatives  True positives  False positives            Precision  \
# LR                   9              16               11               0.5926
# DT                   7              18               19               0.4865
# NB                   3              22              877               0.0245
# KNN                 20               5               14               0.2632
# RF                   9              16               10               0.6154
# SVM                  6              19               23               0.4524
# BOOST                3              22               21               0.5116
# NN1                  8              17               18               0.4857
# NN3                 10              15               17               0.4688
# NN5                  9              16               22               0.4211
# RNN                 19               6                6               0.5000
# LSTM                18               7                6               0.5385
#
#                     Recall              F-score
# LR                  0.6400               0.6154
# DT                  0.7200               0.5806
# NB                  0.8800               0.0476
# KNN                 0.2000               0.2273
# RF                  0.6400               0.6275
# SVM                 0.7600               0.5672
# BOOST               0.8800               0.6471
# NN1                 0.6800               0.5667
# NN3                 0.6000               0.5263
# NN5                 0.6400               0.5079
# RNN                 0.2400               0.3243
# LSTM                0.2800               0.3684

# %% [markdown]
# #### Sample 2 (7812 unique visitors)

# %%
# load performance metrics
lr_8k = pd.read_pickle('../results/model_performance/model_performance_6250_LR.pkl.gz')
dt_8k = pd.read_pickle('../results/model_performance/model_performance_6250_DT.pkl.gz')
nb_8k = pd.read_pickle('../results/model_performance/model_performance_6250_NB.pkl.gz')
knn_8k = pd.read_pickle('../results/model_performance/model_performance_6250_KNN.pkl.gz')
rf_8k = pd.read_pickle('../results/model_performance/model_performance_6250_RF.pkl.gz')
svm_8k = pd.read_pickle('../results/model_performance/model_performance_6250_SVM.pkl.gz')
boost_8k = pd.read_pickle('../results/model_performance/model_performance_6250_BOOST.pkl.gz')
nn1_8k = pd.read_pickle('../results/model_performance/model_performance_6250_NN1.pkl.gz')
nn3_8k = pd.read_pickle('../results/model_performance/model_performance_6250_NN3.pkl.gz')
nn5_8k = pd.read_pickle('../results/model_performance/model_performance_6250_NN5.pkl.gz')
rnn_8k = pd.read_pickle('../results/model_performance/model_performance_6250_RNN.pkl.gz')
lstm_8k = pd.read_pickle('../results/model_performance/model_performance_6250_LSTM.pkl.gz')

# create dataframe with all models
model_performance_8k = lr_8k
for df in [dt_8k, 
           nb_8k, 
           knn_8k, 
           rf_8k, 
           svm_8k, 
           boost_8k, 
           nn1_8k, 
           nn3_8k, 
           nn5_8k, 
           rnn_8k, 
           lstm_8k]:
    model_performance_8k = model_performance_8k.append(df)

model_performance_8k
# Out:
#        Unique visitors train  Unique visitors test  Sessions train  \
# LR                      6250                  1562            8721
# DT                      6250                  1562            8721
# NB                      6250                  1562            8721
# KNN                     6250                  1562            8721
# RF                      6250                  1562            8721
# SVM                     6250                  1562            8721
# BOOST                   6250                  1562            8721
# NN1                     6250                  1562            8721
# NN3                     6250                  1562            8721
# NN5                     6250                  1562            8721
# RNN                     6250                  1562            8721
# LSTM                    6250                  1562            8721
#
#        Sessions test  Features  Training time  Testing time  \
# LR              2015       134              0             0
# DT              2015       134              0             0
# NB              2015       134              0             0
# KNN             2015       134              0             5
# RF              2015       134              0             0
# SVM             2015       134              1             0
# BOOST           2015       134              2             0
# NN1             2015       134              2             0
# NN3             2015       134              3             0
# NN5             2015       134              5             0
# RNN             2015       115             41             1
# LSTM            2015       115            110             2
#
#                   Accuracy                  AUC  True negatives  \
# LR                  0.9806               0.7645            1946
# DT                  0.9797               0.8247            1937
# NB                  0.2164               0.5710             383
# KNN                 0.9742               0.6311            1948
# RF                  0.9846               0.7666            1954
# SVM                 0.9821               0.8347            1941
# BOOST               0.9861               0.8541            1947
# NN1                 0.9851               0.8102            1950
# NN3                 0.9841               0.8357            1945
# NN5                 0.9831               0.8612            1940
# RNN                 0.9732               0.5265            1958
# LSTM                0.9801               0.7296            1949
#
#        False negatives  True positives  False positives            Precision  \
# LR                  26              30               13               0.6977
# DT                  19              37               22               0.6271
# NB                   3              53             1576               0.0325
# KNN                 41              15               11               0.5769
# RF                  26              30                5               0.8571
# SVM                 18              38               18               0.6786
# BOOST               16              40               12               0.7692
# NN1                 21              35                9               0.7955
# NN3                 18              38               14               0.7308
# NN5                 15              41               19               0.6833
# RNN                 53               3                1               0.7500
# LSTM                30              26               10               0.7222
#
#                     Recall              F-score
# LR                  0.5357               0.6061
# DT                  0.6607               0.6435
# NB                  0.9464               0.0629
# KNN                 0.2679               0.3659
# RF                  0.5357               0.6593
# SVM                 0.6786               0.6786
# BOOST               0.7143               0.7407
# NN1                 0.6250               0.7000
# NN3                 0.6786               0.7037
# NN5                 0.7321               0.7069
# RNN                 0.0536               0.1000
# LSTM                0.4643               0.5652

# %% [markdown]
# #### Sample 3 (15625 unique visitors)

# %%
# load performance metrics
lr_16k = pd.read_pickle('../results/model_performance/model_performance_12500_LR.pkl.gz')
dt_16k = pd.read_pickle('../results/model_performance/model_performance_12500_DT.pkl.gz')
nb_16k = pd.read_pickle('../results/model_performance/model_performance_12500_NB.pkl.gz')
knn_16k = pd.read_pickle('../results/model_performance/model_performance_12500_KNN.pkl.gz')
rf_16k = pd.read_pickle('../results/model_performance/model_performance_12500_RF.pkl.gz')
svm_16k = pd.read_pickle('../results/model_performance/model_performance_12500_SVM.pkl.gz')
boost_16k = pd.read_pickle('../results/model_performance/model_performance_12500_BOOST.pkl.gz')
nn1_16k = pd.read_pickle('../results/model_performance/model_performance_12500_NN1.pkl.gz')
nn3_16k = pd.read_pickle('../results/model_performance/model_performance_12500_NN3.pkl.gz')
nn5_16k = pd.read_pickle('../results/model_performance/model_performance_12500_NN5.pkl.gz')
rnn_16k = pd.read_pickle('../results/model_performance/model_performance_12500_RNN.pkl.gz')
lstm_16k = pd.read_pickle('../results/model_performance/model_performance_12500_LSTM.pkl.gz')

# create dataframe with all models
model_performance_16k = lr_16k
for df in [dt_16k, 
           nb_16k, 
           knn_16k, 
           rf_16k, 
           svm_16k, 
           boost_16k, 
           nn1_16k, 
           nn3_16k, 
           nn5_16k, 
           rnn_16k, 
           lstm_16k]:
    model_performance_16k = model_performance_16k.append(df)

model_performance_16k
# Out:
#        Unique visitors train  Unique visitors test  Sessions train  \
# LR                     12500                  3125           17157
# DT                     12500                  3125           17157
# NB                     12500                  3125           17157
# KNN                    12500                  3125           17157
# RF                     12500                  3125           17157
# SVM                    12500                  3125           17157
# BOOST                  12500                  3125           17157
# NN1                    12500                  3125           17157
# NN3                    12500                  3125           17157
# NN5                    12500                  3125           17157
# RNN                    12500                  3125           17157
# LSTM                   12500                  3125           17157
#
#        Sessions test  Features  Training time  Testing time  \
# LR              4323       134              0             0
# DT              4323       134              0             0
# NB              4323       134              0             0
# KNN             4323       134              0            28
# RF              4323       134              0             0
# SVM             4323       134              5             0
# BOOST           4323       134              7             0
# NN1             4323       134              4             0
# NN3             4323       134              6             0
# NN5             4323       134              8             0
# RNN             4323       115             79             3
# LSTM            4323       115            214             4
#
#                   Accuracy                  AUC  True negatives  \
# LR                  0.9845               0.8190            4168
# DT                  0.9810               0.8490            4144
# NB                  0.4115               0.6749            1648
# KNN                 0.9766               0.6985            4167
# RF                  0.9859               0.8374            4169
# SVM                 0.9838               0.8469            4157
# BOOST               0.9864               0.8553            4166
# NN1                 0.9829               0.8111            4163
# NN3                 0.9845               0.8614            4156
# NN5                 0.9845               0.8331            4164
# RNN                 0.9752               0.6095            4186
# LSTM                0.9801               0.7320            4173
#
#        False negatives  True positives  False positives            Precision  \
# LR                  49              88               18               0.8302
# DT                  40              97               42               0.6978
# NB                   6             131             2538               0.0491
# KNN                 82              55               19               0.7432
# RF                  44              93               17               0.8455
# SVM                 41              96               29               0.7680
# BOOST               39              98               20               0.8305
# NN1                 51              86               23               0.7890
# NN3                 37             100               30               0.7692
# NN5                 45              92               22               0.8070
# RNN                107              30                0               1.0000
# LSTM                73              64               13               0.8312
#
#                     Recall              F-score
# LR                  0.6423               0.7243
# DT                  0.7080               0.7029
# NB                  0.9562               0.0934
# KNN                 0.4015               0.5213
# RF                  0.6788               0.7530
# SVM                 0.7007               0.7328
# BOOST               0.7153               0.7686
# NN1                 0.6277               0.6992
# NN3                 0.7299               0.7491
# NN5                 0.6715               0.7331
# RNN                 0.2190               0.3593
# LSTM                0.4672               0.5981

# %% [markdown]
# #### Sample 4 (31250 unique visitors)

# %%
# load performance metrics
lr_31k = pd.read_pickle('../results/model_performance/model_performance_25000_LR.pkl.gz')
dt_31k = pd.read_pickle('../results/model_performance/model_performance_25000_DT.pkl.gz')
nb_31k = pd.read_pickle('../results/model_performance/model_performance_25000_NB.pkl.gz')
knn_31k = pd.read_pickle('../results/model_performance/model_performance_25000_KNN.pkl.gz')
rf_31k = pd.read_pickle('../results/model_performance/model_performance_25000_RF.pkl.gz')
svm_31k = pd.read_pickle('../results/model_performance/model_performance_25000_SVM.pkl.gz')
boost_31k = pd.read_pickle('../results/model_performance/model_performance_25000_BOOST.pkl.gz')
nn1_31k = pd.read_pickle('../results/model_performance/model_performance_25000_NN1.pkl.gz')
nn3_31k = pd.read_pickle('../results/model_performance/model_performance_25000_NN3.pkl.gz')
nn5_31k = pd.read_pickle('../results/model_performance/model_performance_25000_NN5.pkl.gz')
rnn_31k = pd.read_pickle('../results/model_performance/model_performance_25000_RNN.pkl.gz')
lstm_31k = pd.read_pickle('../results/model_performance/model_performance_25000_LSTM.pkl.gz')

# create dataframe with all models
model_performance_31k = lr_31k
for df in [dt_31k, 
           nb_31k, 
           knn_31k, 
           rf_31k, 
           svm_31k, 
           boost_31k, 
           nn1_31k, 
           nn3_31k, 
           nn5_31k, 
           rnn_31k, 
           lstm_31k]:
    model_performance_31k = model_performance_31k.append(df)

model_performance_31k
# Out:
#        Unique visitors train  Unique visitors test  Sessions train  \
# LR                     25000                  6250           34275
# DT                     25000                  6250           34275
# NB                     25000                  6250           34275
# KNN                    25000                  6250           34275
# RF                     25000                  6250           34275
# SVM                    25000                  6250           34275
# BOOST                  25000                  6250           34275
# NN1                    25000                  6250           34275
# NN3                    25000                  6250           34275
# NN5                    25000                  6250           34275
# RNN                    25000                  6250           34275
# LSTM                   25000                  6250           34275
#
#        Sessions test  Features  Training time  Testing time  \
# LR              8560       134              1             0
# DT              8560       134              1             0
# NB              8560       134              0             0
# KNN             8560       134              2           103
# RF              8560       134              0             0
# SVM             8560       134             13             0
# BOOST           8560       134             15             0
# NN1             8560       134              7             0
# NN3             8560       134             11             0
# NN5             8560       134             15             0
# RNN             8560       115            134             5
# LSTM            8560       115            380             9
#
#                   Accuracy                  AUC  True negatives  \
# LR                  0.9801               0.7854            8238
# DT                  0.9762               0.8331            8177
# NB                  0.8929               0.9042            7402
# KNN                 0.9761               0.6949            8251
# RF                  0.9850               0.8137            8266
# SVM                 0.9838               0.8259            8248
# BOOST               0.9868               0.8662            8253
# NN1                 0.9852               0.8138            8267
# NN3                 0.9864               0.8457            8261
# NN5                 0.9848               0.8302            8255
# RNN                 0.9791               0.7444            8251
# LSTM                0.9853               0.8470            8250
#
#        False negatives  True positives  False positives            Precision  \
# LR                 111             152               59               0.7204
# DT                  84             179              120               0.5987
# NB                  22             241              895               0.2121
# KNN                159             104               46               0.6933
# RF                  97             166               31               0.8426
# SVM                 90             173               49               0.7793
# BOOST               69             194               44               0.8151
# NN1                 97             166               30               0.8469
# NN3                 80             183               36               0.8356
# NN5                 88             175               42               0.8065
# RNN                133             130               46               0.7386
# LSTM                79             184               47               0.7965
#
#                     Recall              F-score
# LR                  0.5779               0.6414
# DT                  0.6806               0.6370
# NB                  0.9163               0.3445
# KNN                 0.3954               0.5036
# RF                  0.6312               0.7217
# SVM                 0.6578               0.7134
# BOOST               0.7376               0.7745
# NN1                 0.6312               0.7233
# NN3                 0.6958               0.7593
# NN5                 0.6654               0.7292
# RNN                 0.4943               0.5923
# LSTM                0.6996               0.7449

# %% [markdown]
# #### Sample 5 (62500 unique visitors)

# %%
# load performance metrics
lr_63k = pd.read_pickle('../results/model_performance/model_performance_50000_LR.pkl.gz')
dt_63k = pd.read_pickle('../results/model_performance/model_performance_50000_DT.pkl.gz')
nb_63k = pd.read_pickle('../results/model_performance/model_performance_50000_NB.pkl.gz')
knn_63k = pd.read_pickle('../results/model_performance/model_performance_50000_KNN.pkl.gz')
rf_63k = pd.read_pickle('../results/model_performance/model_performance_50000_RF.pkl.gz')
svm_63k = pd.read_pickle('../results/model_performance/model_performance_50000_SVM.pkl.gz')
boost_63k = pd.read_pickle('../results/model_performance/model_performance_50000_BOOST.pkl.gz')
nn1_63k = pd.read_pickle('../results/model_performance/model_performance_50000_NN1.pkl.gz')
nn3_63k = pd.read_pickle('../results/model_performance/model_performance_50000_NN3.pkl.gz')
nn5_63k = pd.read_pickle('../results/model_performance/model_performance_50000_NN5.pkl.gz')
rnn_63k = pd.read_pickle('../results/model_performance/model_performance_50000_RNN.pkl.gz')
lstm_63k = pd.read_pickle('../results/model_performance/model_performance_50000_LSTM.pkl.gz')

# create dataframe with all models
model_performance_63k = lr_63k
for df in [dt_63k, 
           nb_63k, 
           knn_63k, 
           rf_63k, 
           svm_63k, 
           boost_63k, 
           nn1_63k, 
           nn3_63k, 
           nn5_63k, 
           rnn_63k, 
           lstm_63k]:
    model_performance_63k = model_performance_63k.append(df)

model_performance_63k
# Out:
#        Unique visitors train  Unique visitors test  Sessions train  \
# LR                     50000                 12500           68117
# DT                     50000                 12500           68117
# NB                     50000                 12500           68117
# KNN                    50000                 12500           68117
# RF                     50000                 12500           68117
# SVM                    50000                 12500           68117
# BOOST                  50000                 12500           68117
# NN1                    50000                 12500           68117
# NN3                    50000                 12500           68117
# NN5                    50000                 12500           68117
# RNN                    50000                 12500           68117
# LSTM                   50000                 12500           68117
#
#        Sessions test  Features  Training time  Testing time  \
# LR             16640       134              3             0
# DT             16640       134              2             0
# NB             16640       134              0             0
# KNN            16640       134             11           378
# RF             16640       134              2             0
# SVM            16640       134             32             0
# BOOST          16640       134             33             0
# NN1            16640       134             13             0
# NN3            16640       134             21             0
# NN5            16640       134             29             0
# RNN            16640       115            217            11
# LSTM           16640       115            644            19
#
#                   Accuracy                  AUC  True negatives  \
# LR                  0.9817               0.8047           16025
# DT                  0.9783               0.8338           15937
# NB                  0.9281               0.8994           15007
# KNN                 0.9772               0.7118           16044
# RF                  0.9845               0.8196           16058
# SVM                 0.9837               0.8279           16036
# BOOST               0.9858               0.8646           16034
# NN1                 0.9850               0.8622           16022
# NN3                 0.9847               0.8351           16045
# NN5                 0.9836               0.8702           15990
# RNN                 0.9818               0.8211           16010
# LSTM                0.9834               0.8797           15976
#
#        False negatives  True positives  False positives            Precision  \
# LR                 193             310              112               0.7346
# DT                 161             342              200               0.6310
# NB                  66             437             1130               0.2789
# KNN                287             216               93               0.6990
# RF                 179             324               79               0.8040
# SVM                170             333              101               0.7673
# BOOST              133             370              103               0.7822
# NN1                135             368              115               0.7619
# NN3                163             340               92               0.7870
# NN5                126             377              147               0.7195
# RNN                176             327              127               0.7203
# LSTM               116             387              161               0.7062
#
#                     Recall              F-score
# LR                  0.6163               0.6703
# DT                  0.6799               0.6545
# NB                  0.8688               0.4222
# KNN                 0.4294               0.5320
# RF                  0.6441               0.7152
# SVM                 0.6620               0.7108
# BOOST               0.7356               0.7582
# NN1                 0.7316               0.7465
# NN3                 0.6759               0.7273
# NN5                 0.7495               0.7342
# RNN                 0.6501               0.6834
# LSTM                0.7694               0.7364

# %% [markdown]
# #### Sample 6 (125000 unique visitors)

# %%
# load performance metrics
lr_125k = pd.read_pickle('../results/model_performance/model_performance_100000_LR.pkl.gz')
dt_125k = pd.read_pickle('../results/model_performance/model_performance_100000_DT.pkl.gz')
nb_125k = pd.read_pickle('../results/model_performance/model_performance_100000_NB.pkl.gz')
knn_125k = pd.read_pickle('../results/model_performance/model_performance_100000_KNN.pkl.gz')
rf_125k = pd.read_pickle('../results/model_performance/model_performance_100000_RF.pkl.gz')
svm_125k = pd.read_pickle('../results/model_performance/model_performance_100000_SVM.pkl.gz')
boost_125k = pd.read_pickle('../results/model_performance/model_performance_100000_BOOST.pkl.gz')
nn1_125k = pd.read_pickle('../results/model_performance/model_performance_100000_NN1.pkl.gz')
nn3_125k = pd.read_pickle('../results/model_performance/model_performance_100000_NN3.pkl.gz')
nn5_125k = pd.read_pickle('../results/model_performance/model_performance_100000_NN5.pkl.gz')
rnn_125k = pd.read_pickle('../results/model_performance/model_performance_100000_RNN.pkl.gz')
lstm_125k = pd.read_pickle('../results/model_performance/model_performance_100000_LSTM.pkl.gz')

# create dataframe with all models
model_performance_125k = lr_125k
for df in [dt_125k, 
           nb_125k, 
           knn_125k, 
           rf_125k, 
           svm_125k, 
           boost_125k, 
           nn1_125k, 
           nn3_125k, 
           nn5_125k, 
           rnn_125k, 
           lstm_125k]:
    model_performance_125k = model_performance_125k.append(df)

model_performance_125k
# Out:
#        Unique visitors train  Unique visitors test  Sessions train  \
# LR                    100000                 25000          134558
# DT                    100000                 25000          134558
# NB                    100000                 25000          134558
# KNN                   100000                 25000          134558
# RF                    100000                 25000          134558
# SVM                   100000                 25000          134558
# BOOST                 100000                 25000          134558
# NN1                   100000                 25000          134558
# NN3                   100000                 25000          134558
# NN5                   100000                 25000          134558
# RNN                   100000                 25000          134558
# LSTM                  100000                 25000          134558
#
#        Sessions test  Features  Training time  Testing time  \
# LR             33644       134              6             0
# DT             33644       134              6             0
# NB             33644       134              0             0
# KNN            33644       134             36          1344
# RF             33644       134              4             0
# SVM            33644       134             70             0
# BOOST          33644       134             68             0
# NN1            33644       134             31             0
# NN3            33644       134             39             0
# NN5            33644       134             52             1
# RNN            33644       115            444            25
# LSTM           33644       115           1059            43
#
#                   Accuracy                  AUC  True negatives  \
# LR                  0.9834               0.8261           32380
# DT                  0.9810               0.8627           32215
# NB                  0.9300               0.9035           30351
# KNN                 0.9786               0.7411           32402
# RF                  0.9863               0.8528           32420
# SVM                 0.9842               0.8418           32373
# BOOST               0.9875               0.8840           32394
# NN1                 0.9864               0.8898           32344
# NN3                 0.9870               0.8711           32403
# NN5                 0.9855               0.9019           32284
# RNN                 0.9826               0.8820           32228
# LSTM                0.9855               0.8916           32308
#
#        False negatives  True positives  False positives            Precision  \
# LR                 367             706              191               0.7871
# DT                 283             790              356               0.6894
# NB                 134             939             2220               0.2972
# KNN                550             523              169               0.7558
# RF                 311             762              151               0.8346
# SVM                333             740              198               0.7889
# BOOST              243             830              177               0.8242
# NN1                229             844              227               0.7880
# NN3                271             802              168               0.8268
# NN5                201             872              287               0.7524
# RNN                242             831              343               0.7078
# LSTM               224             849              263               0.7635
#
#                     Recall              F-score
# LR                  0.6580               0.7168
# DT                  0.7363               0.7120
# NB                  0.8751               0.4438
# KNN                 0.4874               0.5926
# RF                  0.7102               0.7674
# SVM                 0.6897               0.7360
# BOOST               0.7735               0.7981
# NN1                 0.7866               0.7873
# NN3                 0.7474               0.7851
# NN5                 0.8127               0.7814
# RNN                 0.7745               0.7397
# LSTM                0.7912               0.7771

# %% [markdown]
# #### Sample 7 (250000 unique visitors)

# %%
# load performance metrics
lr_250k = pd.read_pickle('../results/model_performance/model_performance_200000_LR.pkl.gz')
dt_250k = pd.read_pickle('../results/model_performance/model_performance_200000_DT.pkl.gz')
nb_250k = pd.read_pickle('../results/model_performance/model_performance_200000_NB.pkl.gz')
knn_250k = pd.read_pickle('../results/model_performance/model_performance_200000_KNN.pkl.gz')
rf_250k = pd.read_pickle('../results/model_performance/model_performance_200000_RF.pkl.gz')
svm_250k = pd.read_pickle('../results/model_performance/model_performance_200000_SVM.pkl.gz')
boost_250k = pd.read_pickle('../results/model_performance/model_performance_200000_BOOST.pkl.gz')
nn1_250k = pd.read_pickle('../results/model_performance/model_performance_200000_NN1.pkl.gz')
nn3_250k = pd.read_pickle('../results/model_performance/model_performance_200000_NN3.pkl.gz')
nn5_250k = pd.read_pickle('../results/model_performance/model_performance_200000_NN5.pkl.gz')
rnn_250k = pd.read_pickle('../results/model_performance/model_performance_200000_RNN.pkl.gz')
lstm_250k = pd.read_pickle('../results/model_performance/model_performance_200000_LSTM.pkl.gz')

# create dataframe with all models
model_performance_250k = lr_250k
for df in [dt_250k, 
           nb_250k, 
           knn_250k, 
           rf_250k, 
           svm_250k, 
           boost_250k, 
           nn1_250k, 
           nn3_250k, 
           nn5_250k, 
           rnn_250k, 
           lstm_250k]:
    model_performance_250k = model_performance_250k.append(df)

model_performance_250k
# Out:
#        Unique visitors train  Unique visitors test  Sessions train  \
# LR                    200000                 50000          268891
# DT                    200000                 50000          268891
# NB                    200000                 50000          268891
# KNN                   200000                 50000          268891
# RF                    200000                 50000          268891
# SVM                   200000                 50000          268891
# BOOST                 200000                 50000          268891
# NN1                   200000                 50000          268891
# NN3                   200000                 50000          268891
# NN5                   200000                 50000          268891
# RNN                   200000                 50000          268891
# LSTM                  200000                 50000          268891
#
#        Sessions test  Features  Training time  Testing time  \
# LR             67127       134             13             0
# DT             67127       134             16             0
# NB             67127       134              1             0
# KNN            67127       134            115          3844
# RF             67127       134              9             0
# SVM            67127       134            167             0
# BOOST          67127       134            152             0
# NN1            67127       134             54             1
# NN3            67127       134             76             1
# NN5            67127       134            110             2
# RNN            67127       115            841            50
# LSTM           67127       115           2401            87
#
#                   Accuracy                  AUC  True negatives  \
# LR                  0.9848               0.8299           64721
# DT                  0.9813               0.8509           64389
# NB                  0.9340               0.9086           60858
# KNN                 0.9821               0.7714           64784
# RF                  0.9874               0.8498           64812
# SVM                 0.9850               0.8400           64688
# BOOST               0.9882               0.8769           64752
# NN1                 0.9881               0.8451           64882
# NN3                 0.9882               0.8693           64787
# NN5                 0.9883               0.8972           64674
# RNN                 0.9844               0.8754           64496
# LSTM                0.9865               0.8890           64582
#
#        False negatives  True positives  False positives            Precision  \
# LR                 699            1386              321               0.8120
# DT                 601            1484              653               0.6944
# NB                 247            1838             4184               0.3052
# KNN                945            1140              258               0.8155
# RF                 619            1466              230               0.8644
# SVM                656            1429              354               0.8015
# BOOST              504            1581              290               0.8450
# NN1                641            1444              160               0.9002
# NN3                537            1548              255               0.8586
# NN5                417            1668              368               0.8193
# RNN                502            1583              546               0.7435
# LSTM               448            1637              460               0.7806
#
#                     Recall              F-score
# LR                  0.6647               0.7310
# DT                  0.7118               0.7030
# NB                  0.8815               0.4534
# KNN                 0.5468               0.6546
# RF                  0.7031               0.7755
# SVM                 0.6854               0.7389
# BOOST               0.7583               0.7993
# NN1                 0.6926               0.7829
# NN3                 0.7424               0.7963
# NN5                 0.8000               0.8095
# RNN                 0.7592               0.7513
# LSTM                0.7851               0.7829

# %% [markdown]
# #### Sample 8 (500000 unique visitors)

# %%
# load performance metrics
lr_500k = pd.read_pickle('../results/model_performance/model_performance_400000_LR.pkl.gz')
dt_500k = pd.read_pickle('../results/model_performance/model_performance_400000_DT.pkl.gz')
nb_500k = pd.read_pickle('../results/model_performance/model_performance_400000_NB.pkl.gz')
knn_500k = pd.read_pickle('../results/model_performance/model_performance_400000_KNN.pkl.gz')
rf_500k = pd.read_pickle('../results/model_performance/model_performance_400000_RF.pkl.gz')
svm_500k = pd.read_pickle('../results/model_performance/model_performance_400000_SVM.pkl.gz')
boost_500k = pd.read_pickle('../results/model_performance/model_performance_400000_BOOST.pkl.gz')
nn1_500k = pd.read_pickle('../results/model_performance/model_performance_400000_NN1.pkl.gz')
nn3_500k = pd.read_pickle('../results/model_performance/model_performance_400000_NN3.pkl.gz')
nn5_500k = pd.read_pickle('../results/model_performance/model_performance_400000_NN5.pkl.gz')
rnn_500k = pd.read_pickle('../results/model_performance/model_performance_400000_RNN.pkl.gz')
lstm_500k = pd.read_pickle('../results/model_performance/model_performance_400000_LSTM.pkl.gz')

# create dataframe with all models
model_performance_500k = lr_500k
for df in [dt_500k, 
           nb_500k, 
           knn_500k, 
           rf_500k, 
           svm_500k, 
           boost_500k, 
           nn1_500k, 
           nn3_500k, 
           nn5_500k, 
           rnn_500k, 
           lstm_500k]:
    model_performance_500k = model_performance_500k.append(df)

model_performance_500k
# Out:
#        Unique visitors train  Unique visitors test  Sessions train  \
# LR                    400000                100000          536539
# DT                    400000                100000          536539
# NB                    400000                100000          536539
# KNN                   400000                100000          536539
# RF                    400000                100000          536539
# SVM                   400000                100000          536539
# BOOST                 400000                100000          536539
# NN1                   400000                100000          536539
# NN3                   400000                100000          536539
# NN5                   400000                100000          536539
# RNN                   400000                100000          536539
# LSTM                  400000                100000          536539
#
#        Sessions test  Features  Training time  Testing time  \
# LR            135122       134             30             0
# DT            135122       134             34             0
# NB            135122       134              3             0
# KNN           135122       134            560         12321
# RF            135122       134             25             0
# SVM           135122       134            308             0
# BOOST         135122       134            333             0
# NN1           135122       134            120             2
# NN3           135122       134            159             3
# NN5           135122       134            219             4
# RNN           135122       115           1790           114
# LSTM          135122       115           4191           186
#
#                   Accuracy                  AUC  True negatives  \
# LR                  0.9835               0.8235          130076
# DT                  0.9797               0.8526          129275
# NB                  0.9402               0.9051          123296
# KNN                 0.9820               0.7806          130250
# RF                  0.9863               0.8468          130258
# SVM                 0.9841               0.8326          130082
# BOOST               0.9872               0.8764          130110
# NN1                 0.9875               0.8737          130181
# NN3                 0.9869               0.8601          130220
# NN5                 0.9871               0.8632          130225
# RNN                 0.9811               0.8546          129457
# LSTM                0.9854               0.8333          130244
#
#        False negatives  True positives  False positives            Precision  \
# LR                1501            2820              725               0.7955
# DT                1223            3098             1526               0.6700
# NB                 572            3749             7505               0.3331
# KNN               1878            2443              551               0.8160
# RF                1306            3015              543               0.8474
# SVM               1423            2898              719               0.8012
# BOOST             1045            3276              691               0.8258
# NN1               1071            3250              620               0.8398
# NN3               1190            3131              581               0.8435
# NN5               1163            3158              576               0.8457
# RNN               1212            3109             1344               0.6982
# LSTM              1422            2899              557               0.8388
#
#                     Recall              F-score
# LR                  0.6526               0.7170
# DT                  0.7170               0.6927
# NB                  0.8676               0.4814
# KNN                 0.5654               0.6679
# RF                  0.6978               0.7653
# SVM                 0.6707               0.7302
# BOOST               0.7582               0.7905
# NN1                 0.7521               0.7936
# NN3                 0.7246               0.7795
# NN5                 0.7308               0.7841
# RNN                 0.7195               0.7087
# LSTM                0.6709               0.7455

# %% [markdown]
# #### Sample 9 (1000000 unique visitors)

# %%
# load performance metrics
lr_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_LR.pkl.gz')
dt_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_DT.pkl.gz')
nb_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_NB.pkl.gz')
knn_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_KNN.pkl.gz')
rf_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_RF.pkl.gz')
svm_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_SVM.pkl.gz')
boost_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_BOOST.pkl.gz')
nn1_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_NN1.pkl.gz')
nn3_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_NN3.pkl.gz')
nn5_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_NN5.pkl.gz')
rnn_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_RNN.pkl.gz')
lstm_1000k = pd.read_pickle('../results/model_performance/model_performance_800000_LSTM.pkl.gz')

# create dataframe with all models
model_performance_1000k = lr_1000k
for df in [dt_1000k, 
           nb_1000k, 
           knn_1000k, 
           rf_1000k, 
           svm_1000k, 
           boost_1000k, 
           nn1_1000k, 
           nn3_1000k, 
           nn5_1000k, 
           rnn_1000k, 
           lstm_1000k]:
    model_performance_1000k = model_performance_1000k.append(df)

# replace missing metrics with nan for RNN
model_performance_1000k.at['RNN', 'Accuracy'] = np.nan
model_performance_1000k.at['RNN', 'AUC'] = np.nan
model_performance_1000k.at['RNN', 'Recall'] = np.nan

model_performance_1000k
# Out:
#        Unique visitors train  Unique visitors test  Sessions train  \
# LR                    800000                200000         1072626
# DT                    800000                200000         1072626
# NB                    800000                200000         1072626
# KNN                   800000                200000         1072626
# RF                    800000                200000         1072626
# SVM                   800000                200000         1072626
# BOOST                 800000                200000         1072626
# NN1                   800000                200000         1072626
# NN3                   800000                200000         1072626
# NN5                   800000                200000         1072626
# RNN                   800000                200000         1072626
# LSTM                  800000                200000         1072626
#
#        Sessions test  Features  Training time  Testing time  \
# LR            270009       134             66             0
# DT            270009       134             79             0
# NB            270009       134              5             1
# KNN           270009       134           4225         38568
# RF            270009       134             79             1
# SVM           270009       134            694             0
# BOOST         270009       134            778             2
# NN1           270009       134            250             5
# NN3           270009       134            328             5
# NN5           270009       134            436             9
# RNN           270009       115           3174           273
# LSTM          270009       115           8840           469
#
#                   Accuracy                  AUC  True negatives  \
# LR                  0.9836               0.8267          259921
# DT                  0.9777               0.8519          257815
# NB                  0.9406               0.8985          246644
# KNN                 0.9825               0.7907          260250
# RF                  0.9869               0.8530          260367
# SVM                 0.9843               0.8406          259871
# BOOST               0.9873               0.8736          260106
# NN1                 0.9876               0.8549          260539
# NN3                 0.9879               0.8732          260284
# NN5                 0.9874               0.8593          260399
# RNN                    nan                  nan               0
# LSTM                0.9836               0.8638          259250
#
#        False negatives  True positives  False positives            Precision  \
# LR                2932            5667             1489               0.7919
# DT                2428            6171             3595               0.6319
# NB                1260            7339            14766               0.3320
# KNN               3561            5038             1160               0.8128
# RF                2494            6105             1043               0.8541
# SVM               2690            5909             1539               0.7934
# BOOST             2131            6468             1304               0.8322
# NN1               2467            6132              871               0.8756
# NN3               2144            6455             1126               0.8515
# NN5               2387            6212             1011               0.8600
# RNN             261410               0                0                  nan
# LSTM              2271            6328             2160               0.7455
#
#                     Recall              F-score
# LR                  0.6590               0.7194
# DT                  0.7176               0.6720
# NB                  0.8535               0.4780
# KNN                 0.5859               0.6809
# RF                  0.7100               0.7754
# SVM                 0.6872               0.7365
# BOOST               0.7522               0.7902
# NN1                 0.7131               0.7861
# NN3                 0.7507               0.7979
# NN5                 0.7224               0.7852
# RNN                    nan                  nan
# LSTM                0.7359               0.7407

# %% [markdown]
# #### Sample 10 (2000000 unique visitors)

# %%
# load performance metrics
lr_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_LR.pkl.gz')
dt_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_DT.pkl.gz')
nb_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_NB.pkl.gz')
knn_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_KNN.pkl.gz')
rf_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_RF.pkl.gz')
svm_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_SVM.pkl.gz')
boost_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_BOOST.pkl.gz')
nn1_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_NN1.pkl.gz')
nn3_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_NN3.pkl.gz')
nn5_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_NN5.pkl.gz')
rnn_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_RNN.pkl.gz')
lstm_2000k = pd.read_pickle('../results/model_performance/model_performance_1600000_LSTM.pkl.gz')

# create dataframe with all models
model_performance_2000k = lr_2000k
for df in [dt_2000k, 
           nb_2000k,
           knn_2000k,
           rf_2000k, 
           svm_2000k, 
           boost_2000k, 
           nn1_2000k, 
           nn3_2000k, 
           nn5_2000k, 
           rnn_2000k, 
           lstm_2000k]:
    model_performance_2000k = model_performance_2000k.append(df)

# replace missing metrics with nan for RNN
model_performance_2000k.at['RNN', 'Accuracy'] = np.nan
model_performance_2000k.at['RNN', 'AUC'] = np.nan
model_performance_2000k.at['RNN', 'Recall'] = np.nan

model_performance_2000k
# Out:
#        Unique visitors train  Unique visitors test  Sessions train  \
# LR                   1600000                400000         2150922
# DT                   1600000                400000         2150922
# NB                   1600000                400000         2150922
# KNN                  1600000                400000         2150922
# RF                   1600000                400000         2150922
# SVM                  1600000                400000         2150922
# BOOST                1600000                400000         2150922
# NN1                  1600000                400000         2150922
# NN3                  1600000                400000         2150922
# NN5                  1600000                400000         2150922
# RNN                  1600000                400000         2150922
# LSTM                 1600000                400000         2150922
#
#        Sessions test  Features  Training time  Testing time  \
# LR            536678       134            197             0
# DT            536678       134            211             1
# NB            536678       134             10             2
# KNN           536678       134          16557         31631
# RF            536678       134            209             3
# SVM           536678       134           1445             0
# BOOST         536678       134           1460             3
# NN1           536678       134            554            10
# NN3           536678       134            743            13
# NN5           536678       134            945            21
# RNN           536678       115           7081           393
# LSTM          536678       115          20196           781
#
#                   Accuracy                  AUC  True negatives  \
# LR                  0.9838               0.8285          516605
# DT                  0.9816               0.8618          514246
# NB                  0.9415               0.9009          490561
# KNN                 0.9828               0.7980          517140
# RF                  0.9875               0.8616          517501
# SVM                 0.9843               0.8380          516546
# BOOST               0.9878               0.8805          516987
# NN1                 0.9889               0.8886          517309
# NN3                 0.9890               0.8810          517630
# NN5                 0.9882               0.8586          517975
# RNN                    nan                  nan               0
# LSTM                0.9833               0.8713          514823
#
#        False negatives  True positives  False positives            Precision  \
# LR                5781           11360             2932               0.7949
# DT                4564           12577             5291               0.7039
# NB                2440           14701            28976               0.3366
# KNN               6847           10294             2397               0.8111
# RF                4678           12463             2036               0.8596
# SVM               5455           11686             2991               0.7962
# BOOST             4012           13129             2550               0.8374
# NN1               3746           13395             2228               0.8574
# NN3               4017           13124             1907               0.8731
# NN5               4795           12346             1562               0.8877
# RNN             519537               0                0                  nan
# LSTM              4256           12885             4714               0.7321
#
#                     Recall              F-score
# LR                  0.6627               0.7228
# DT                  0.7337               0.7185
# NB                  0.8577               0.4834
# KNN                 0.6005               0.6901
# RF                  0.7271               0.7878
# SVM                 0.6818               0.7346
# BOOST               0.7659               0.8001
# NN1                 0.7815               0.8177
# NN3                 0.7656               0.8159
# NN5                 0.7203               0.7953
# RNN                    nan                  nan
# LSTM                0.7517               0.7418

# %% [markdown]
# #### Learning curves - AUC

# %%
# create dataframe with AUC for all samples and models
learning_curves_auc = pd.DataFrame()
learning_curves_auc['unique_visitors_train'] = [3125, 6250, 12500, 25000, 50000, 100000, 200000, 400000, 800000, 1600000]
for model in ['LR', 'DT', 'NB', 'KNN', 'RF', 'SVM', 'BOOST', 'NN1', 'NN3', 'NN5', 'RNN', 'LSTM']:
    learning_curves_auc[model] = [model_performance_4k.at[model,'AUC'], 
                                  model_performance_8k.at[model,'AUC'], 
                                  model_performance_16k.at[model,'AUC'], 
                                  model_performance_31k.at[model,'AUC'], 
                                  model_performance_63k.at[model,'AUC'], 
                                  model_performance_125k.at[model,'AUC'], 
                                  model_performance_250k.at[model,'AUC'], 
                                  model_performance_500k.at[model,'AUC'], 
                                  model_performance_1000k.at[model,'AUC'], 
                                  model_performance_2000k.at[model,'AUC']]
    
# some modifications for plotting
learning_curves_auc['unique_visitors (thousands)'] = learning_curves_auc['unique_visitors_train'].apply(lambda x: str(int(x/1000)))
learning_curves_auc.at[0, 'unique_visitors (thousands)'] = '3'
learning_curves_auc.at[1, 'unique_visitors (thousands)'] = '6'
learning_curves_auc.at[2, 'unique_visitors (thousands)'] = '13'
learning_curves_auc.at[8, 'RNN'] = np.nan
learning_curves_auc.at[9, 'RNN'] = np.nan

# %%
# Figure 2
plt.figure(figsize=(12,8))

plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['LR'], linewidth=2, marker='v', markersize=10)
plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['DT'], linewidth=2, marker='X', markersize=10)
plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['NB'], linewidth=2, marker='o', markersize=10)
plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['KNN'], linewidth=2, marker='P', markersize=10)
plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['RF'], linewidth=2, marker='<', markersize=10)
plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['SVM'], linewidth=2, marker='>', markersize=10)
plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['BOOST'], linewidth=2, marker='s', markersize=10)
plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['NN1'], linewidth=2, marker='p', markersize=10)
plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['NN3'], linewidth=2, marker='*', markersize=10)
plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['NN5'], linewidth=2, marker='^', markersize=10)
plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['RNN'], linewidth=2, marker='h', markersize=10)
plt.plot(learning_curves_auc['unique_visitors (thousands)'], learning_curves_auc['LSTM'], marker='H', markersize=10)
#plt.title('Learning curves', fontsize=16)
plt.ylabel('AUC', fontsize=16)
plt.xlabel('Unique visitors in training set (thousands)', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.legend(title='Models', title_fontsize=12, fontsize=12)
plt.grid(True)

plt.tight_layout()
plt.savefig('learning_curves_auc.png')
plt.show()

# %% [markdown]
# #### Learning curve - F-score

# %%
# create dataframe with F-score for all samples and models
learning_curves_f_score = pd.DataFrame()
learning_curves_f_score['unique_visitors_train'] = [3125, 6250, 12500, 25000, 50000, 100000, 200000, 400000, 800000, 1600000]
for model in ['LR', 'DT', 'NB', 'KNN', 'RF', 'SVM', 'BOOST', 'NN1', 'NN3', 'NN5', 'RNN', 'LSTM']:
    learning_curves_f_score[model] = [model_performance_4k.at[model,'F-score'], 
                                  model_performance_8k.at[model,'F-score'], 
                                  model_performance_16k.at[model,'F-score'], 
                                  model_performance_31k.at[model,'F-score'], 
                                  model_performance_63k.at[model,'F-score'], 
                                  model_performance_125k.at[model,'F-score'], 
                                  model_performance_250k.at[model,'F-score'], 
                                  model_performance_500k.at[model,'F-score'], 
                                  model_performance_1000k.at[model,'F-score'], 
                                  model_performance_2000k.at[model,'F-score']]
    
# some modifications for plotting
learning_curves_f_score['unique_visitors (thousands)'] = learning_curves_f_score['unique_visitors_train'].apply(lambda x: str(int(x/1000)))
learning_curves_f_score.at[0, 'unique_visitors (thousands)'] = '3'
learning_curves_f_score.at[1, 'unique_visitors (thousands)'] = '6'
learning_curves_f_score.at[2, 'unique_visitors (thousands)'] = '13'
learning_curves_f_score.at[8, 'RNN'] = np.nan
learning_curves_f_score.at[9, 'RNN'] = np.nan

# %%
# Figure 2
plt.figure(figsize=(12,8))

plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['LR'], linewidth=2, marker='v', markersize=10)
plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['DT'], linewidth=2, marker='X', markersize=10)
plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['NB'], linewidth=2, marker='o', markersize=10)
plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['KNN'], linewidth=2, marker='P', markersize=10)
plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['RF'], linewidth=2, marker='<', markersize=10)
plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['SVM'], linewidth=2, marker='>', markersize=10)
plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['BOOST'], linewidth=2, marker='s', markersize=10)
plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['NN1'], linewidth=2, marker='p', markersize=10)
plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['NN3'], linewidth=2, marker='*', markersize=10)
plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['NN5'], linewidth=2, marker='^', markersize=10)
plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['RNN'], linewidth=2, marker='h', markersize=10)
plt.plot(learning_curves_f_score['unique_visitors (thousands)'], learning_curves_f_score['LSTM'], linewidth=2, marker='H', markersize=10)
#plt.title('Learning curves', fontsize=16)
plt.ylabel('F-score', fontsize=16)
plt.xlabel('Unique visitors in training set (thousands)', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.legend(title='Models', title_fontsize=12, fontsize=12)
plt.grid(True)

plt.tight_layout()
plt.savefig('learning_curves_f_score.png')
plt.show()

# %% [markdown]
# #### AUC ranking

# %%
# compute ranks based on AUC for all models and samples
learning_curves_auc_rank = learning_curves_auc.drop(['unique_visitors_train', 'unique_visitors (thousands)'], axis=1).rank(axis=1, ascending=False)

for model in ['LR', 'DT', 'NB', 'KNN', 'RF', 'SVM', 'BOOST', 'NN1', 'NN3', 'NN5', 'RNN', 'LSTM']:
    learning_curves_auc_rank[model] = learning_curves_auc_rank[model].apply(lambda x: int(x) if pd.notnull(x) else x)
    learning_curves_auc_rank.at[10, model] = learning_curves_auc_rank[model].mean()

learning_curves_auc_rank['unique_visitors (thousands)'] = learning_curves_auc['unique_visitors (thousands)']
learning_curves_auc_rank.at[10, 'unique_visitors (thousands)'] = 'mean rank'

learning_curves_auc_rank
# Out:
#                      LR                   DT                   NB  \
# 0                6.0000               3.0000              12.0000
# 1                8.0000               5.0000              11.0000
# 2                7.0000               3.0000              11.0000
# 3               10.0000               5.0000               1.0000
# 4               11.0000               7.0000               1.0000
# 5               11.0000               8.0000               1.0000
# 6               11.0000               7.0000               1.0000
# 7               11.0000               7.0000               1.0000
# 8               10.0000               8.0000               1.0000
# 9               10.0000               6.0000               1.0000
# 10               9.5000               5.9000               4.1000
#
#                     KNN                   RF                  SVM  \
# 0               11.0000               5.0000               2.0000
# 1               10.0000               7.0000               4.0000
# 2               10.0000               5.0000               4.0000
# 3               12.0000               9.0000               7.0000
# 4               12.0000              10.0000               8.0000
# 5               12.0000               9.0000              10.0000
# 6               12.0000               8.0000              10.0000
# 7               12.0000               8.0000              10.0000
# 8               11.0000               7.0000               9.0000
# 9               11.0000               7.0000               9.0000
# 10              11.3000               7.5000               7.3000
#
#                   BOOST                  NN1                  NN3  \
# 0                1.0000               4.0000               8.0000
# 1                2.0000               6.0000               3.0000
# 2                2.0000               8.0000               1.0000
# 3                2.0000               8.0000               4.0000
# 4                4.0000               5.0000               6.0000
# 5                5.0000               4.0000               7.0000
# 6                4.0000               9.0000               6.0000
# 7                2.0000               3.0000               5.0000
# 8                2.0000               6.0000               3.0000
# 9                4.0000               2.0000               3.0000
# 10               2.8000               5.5000               4.6000
#
#                     NN5                  RNN                 LSTM  \
# 0                7.0000              10.0000               9.0000
# 1                1.0000              12.0000               9.0000
# 2                6.0000              12.0000               9.0000
# 3                6.0000              11.0000               3.0000
# 4                3.0000               9.0000               2.0000
# 5                2.0000               6.0000               3.0000
# 6                2.0000               5.0000               3.0000
# 7                4.0000               6.0000               9.0000
# 8                5.0000                  nan               4.0000
# 9                8.0000                  nan               5.0000
# 10               4.4000               8.8750               5.6000
#
#    unique_visitors (thousands)
# 0                            3
# 1                            6
# 2                           13
# 3                           25
# 4                           50
# 5                          100
# 6                          200
# 7                          400
# 8                          800
# 9                         1600
# 10                   mean rank

# %%
# get average rank based on AUC for each model
auc_rank = pd.DataFrame(index=['LR', 'DT', 'NB', 'KNN', 'RF', 'SVM', 'BOOST', 'NN1', 'NN3', 'NN5', 'RNN', 'LSTM'])
auc_rank['Mean rank'] = learning_curves_auc_rank.iloc[10]
auc_rank.sort_values('Mean rank', ascending=True, inplace=True)
auc_rank['Mean rank'] = auc_rank['Mean rank'].apply(lambda x: str(x)[:3])
auc_rank.at['KNN', 'Mean rank'] = str(11.3)
auc_rank
# Out:
#       Mean rank
# BOOST       2.8
# NB          4.1
# NN5         4.4
# NN3         4.6
# NN1         5.5
# LSTM        5.6
# DT          5.9
# SVM         7.3
# RF          7.5
# RNN         8.8
# LR          9.5
# KNN        11.3

# %% [markdown]
# #### AUC ranking Friedman test

# %%
# compute average rank based on AUC
print('Average rank based on AUC: ', auc_rank['Mean rank'].astype(np.float64).mean())

# compute chi squared value for F-test
F_Chi_squared = (12*10)/(12*(12+1))*(sum(auc_rank['Mean rank'].astype(np.float64)**2)-((12*((12+1)**2))/4))
print('Chi squared value for F-test: ', F_Chi_squared)

# compute F-value for F-test
F_F = ((10-1)*F_Chi_squared)/(10*(12-1)-F_Chi_squared)
print('F-value for F-test: ', F_F)

# compute critical distance for Nemenyi test
from math import sqrt
CD = 3.268003591*(sqrt((12*(12+1))/(6*10)))
print('Critical distance for Nemenyi test: ', CD)

# critical value for F-test: https://www.danielsoper.com/statcalc/calculator.aspx?id=4
# critical value for Nemenyi test: https://kourentzes.com/forecasting/2014/05/01/critical-values-for-the-nemenyi-test/
# Out:
# Average rank based on AUC:  6.441666666666666
# Chi squared value for F-test:  45.776923076923076
# F-value for F-test:  6.4150197628458505
# Critical distance for Nemenyi test:  5.269497454601447

# %% [markdown]
# #### F-score ranking

# %%
# compute ranks based on F-score for all models and samples
learning_curves_f_score_rank = learning_curves_f_score.drop(['unique_visitors_train', 'unique_visitors (thousands)'], axis=1).rank(axis=1, ascending=False)

for model in ['LR', 'DT', 'NB', 'KNN', 'RF', 'SVM', 'BOOST', 'NN1', 'NN3', 'NN5', 'RNN', 'LSTM']:
    learning_curves_f_score_rank[model] = learning_curves_f_score_rank[model].apply(lambda x: int(x) if pd.notnull(x) else x)
    learning_curves_f_score_rank.at[10, model] = learning_curves_f_score_rank[model].mean()

learning_curves_f_score_rank['unique_visitors (thousands)'] = learning_curves_f_score['unique_visitors (thousands)']
learning_curves_f_score_rank.at[10, 'unique_visitors (thousands)'] = 'mean rank'

learning_curves_f_score_rank
# Out:
#                      LR                   DT                   NB  \
# 0                3.0000               4.0000              12.0000
# 1                8.0000               7.0000              12.0000
# 2                6.0000               7.0000              12.0000
# 3                8.0000               9.0000              12.0000
# 4                9.0000              10.0000              12.0000
# 5                9.0000              10.0000              12.0000
# 6                9.0000              10.0000              12.0000
# 7                8.0000              10.0000              12.0000
# 8                8.0000              10.0000              11.0000
# 9                8.0000               9.0000              11.0000
# 10               7.6000               8.6000              11.8000
#
#                     KNN                   RF                  SVM  \
# 0               11.0000               2.0000               5.0000
# 1               10.0000               6.0000               5.0000
# 2               10.0000               2.0000               5.0000
# 3               11.0000               6.0000               7.0000
# 4               11.0000               6.0000               7.0000
# 5               11.0000               6.0000               8.0000
# 6               11.0000               6.0000               8.0000
# 7               11.0000               5.0000               7.0000
# 8                9.0000               5.0000               7.0000
# 9               10.0000               5.0000               7.0000
# 10              10.5000               4.9000               6.6000
#
#                   BOOST                  NN1                  NN3  \
# 0                1.0000               6.0000               7.0000
# 1                1.0000               4.0000               3.0000
# 2                1.0000               8.0000               3.0000
# 3                1.0000               5.0000               2.0000
# 4                1.0000               2.0000               5.0000
# 5                1.0000               2.0000               3.0000
# 6                2.0000               5.0000               3.0000
# 7                2.0000               1.0000               4.0000
# 8                2.0000               3.0000               1.0000
# 9                3.0000               1.0000               2.0000
# 10               1.5000               3.7000               3.3000
#
#                     NN5                  RNN                 LSTM  \
# 0                8.0000              10.0000               9.0000
# 1                2.0000              11.0000               9.0000
# 2                4.0000              11.0000               9.0000
# 3                4.0000              10.0000               3.0000
# 4                4.0000               8.0000               3.0000
# 5                4.0000               7.0000               5.0000
# 6                1.0000               7.0000               4.0000
# 7                3.0000               9.0000               6.0000
# 8                4.0000                  nan               6.0000
# 9                4.0000                  nan               6.0000
# 10               3.8000               9.1250               6.0000
#
#    unique_visitors (thousands)
# 0                            3
# 1                            6
# 2                           13
# 3                           25
# 4                           50
# 5                          100
# 6                          200
# 7                          400
# 8                          800
# 9                         1600
# 10                   mean rank

# %%
# get average rank based on F-score for each model
f_score_rank = pd.DataFrame(index=['LR', 'DT', 'NB', 'KNN', 'RF', 'SVM', 'BOOST', 'NN1', 'NN3', 'NN5', 'RNN', 'LSTM'])
f_score_rank['Mean rank'] = learning_curves_f_score_rank.iloc[10]
f_score_rank.sort_values('Mean rank', ascending=True, inplace=True)
f_score_rank['Mean rank'] = f_score_rank['Mean rank'].apply(lambda x: str(x)[:3])
f_score_rank.at['NB', 'Mean rank'] = str(11.8)
f_score_rank.at['KNN', 'Mean rank'] = str(10.5)
f_score_rank
# Out:
#       Mean rank
# BOOST       1.5
# NN3         3.3
# NN1         3.7
# NN5         3.8
# RF          4.9
# LSTM        6.0
# SVM         6.6
# LR          7.6
# DT          8.6
# RNN         9.1
# KNN        10.5
# NB         11.8

# %% [markdown]
# #### F-score ranking Friedman test

# %%
# compute average rank based on F-score
print('Average rank based on F-score: ', f_score_rank['Mean rank'].astype(np.float64).mean())

# compute chi square value for F-test
F_Chi_squared = (12*10)/(12*(12+1))*(sum(f_score_rank['Mean rank'].astype(np.float64)**2)-((12*((12+1)**2))/4))
print('Chi square value for F-test: ', F_Chi_squared)

# compute F-value for F-test
F_F = ((10-1)*F_Chi_squared)/(10*(12-1)-F_Chi_squared)
print('F-value for F-test: ', F_F)

# compute critical distance for Nemenyi test
from math import sqrt
CD = 3.268003591*(sqrt((12*(12+1))/(6*10)))
print('Critical distance for Nemenyi test: ', CD)

# critical value for F-test: https://www.danielsoper.com/statcalc/calculator.aspx?id=4
# critical value for Nemenyi test: https://kourentzes.com/forecasting/2014/05/01/critical-values-for-the-nemenyi-test/
# Out:
# Average rank based on F-score:  6.45
# Chi square value for F-test:  78.35384615384616
# F-value for F-test:  22.283422459893057
# Critical distance for Nemenyi test:  5.269497454601447

# %% [markdown]
# #### Ranks for all models and metrics

# %%
# get ranks for all models and metrics and compute difference between a model's ranks
ranks = pd.merge(auc_rank, f_score_rank, suffixes=(' (AUC)', (' (F-score)')), how='inner', left_index=True, right_index=True).sort_index()
ranks['Mean rank (AUC)'] = ranks['Mean rank (AUC)'].astype(np.float64)
ranks['Mean rank (F-score)'] = ranks['Mean rank (F-score)'].astype(np.float64)
ranks['Absolute difference'] = abs(ranks['Mean rank (AUC)']-ranks['Mean rank (F-score)'])
pd.options.display.float_format = '{:20,.1f}'.format
ranks
# Out:
#            Mean rank (AUC)  Mean rank (F-score)  Absolute difference
# BOOST                  2.8                  1.5                  1.3
# DT                     5.9                  8.6                  2.7
# KNN                   11.3                 10.5                  0.8
# LR                     9.5                  7.6                  1.9
# LSTM                   5.6                  6.0                  0.4
# NB                     4.1                 11.8                  7.7
# NN1                    5.5                  3.7                  1.8
# NN3                    4.6                  3.3                  1.3
# NN5                    4.4                  3.8                  0.6
# RF                     7.5                  4.9                  2.6
# RNN                    8.8                  9.1                  0.3
# SVM                    7.3                  6.6                  0.7

# %%
# reset float format display option
pd.options.display.float_format = '{:20,.4f}'.format

# %% [markdown]
# ### 6.3. Robustness

# %% [markdown]
# #### Cross validation with 8000 unique visitors

# %%
# load cross validation metrics
cv_8k_lr = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_LR.pkl.gz')
cv_8k_dt = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_DT.pkl.gz')
cv_8k_nb = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_NB.pkl.gz')
cv_8k_knn = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_KNN.pkl.gz')
cv_8k_rf = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_RF.pkl.gz')
cv_8k_svm = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_SVM.pkl.gz')
cv_8k_boost = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_BOOST.pkl.gz')
cv_8k_nn1 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_NN1.pkl.gz')
cv_8k_nn3 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_NN3.pkl.gz')
cv_8k_nn5 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_NN5.pkl.gz')
cv_8k_rnn = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_RNN.pkl.gz')
cv_8k_lstm = pd.read_pickle('../results/cross_validation/cross_validation_metrics_6250_LSTM.pkl.gz')

# create dataframe with all models
cv_8k = cv_8k_lr
for df in [cv_8k_dt, cv_8k_nb, cv_8k_knn, cv_8k_rf, cv_8k_svm, cv_8k_boost, cv_8k_nn1, cv_8k_nn3, cv_8k_nn5, cv_8k_rnn, cv_8k_lstm]:
    cv_8k = cv_8k.append(df)
    
cv_8k[['Accuracy', 'AUC', 'Precision', 'Recall', 'F-score']]
# Out:
#               Accuracy              AUC        Precision           Recall  \
# LR     0.9808 (0.0044)  0.7791 (0.0422)   0.736 (0.0775)  0.5647 (0.0855)
# DT     0.9794 (0.0045)   0.831 (0.0374)  0.6501 (0.0985)   0.673 (0.0747)
# NB     0.2673 (0.0285)  0.6098 (0.0168)  0.0375 (0.0081)  0.9736 (0.0398)
# KNN    0.9734 (0.0038)  0.6367 (0.0433)  0.6158 (0.1112)  0.2788 (0.0886)
# RF      0.9821 (0.006)   0.7799 (0.067)  0.7934 (0.0946)  0.5644 (0.1352)
# SVM    0.9764 (0.0173)  0.8118 (0.0251)  0.6746 (0.1756)  0.6366 (0.0464)
# BOOST  0.9843 (0.0048)  0.8369 (0.0426)  0.7692 (0.0738)  0.6803 (0.0856)
# NN1    0.9826 (0.0057)  0.8363 (0.0422)  0.7337 (0.0715)  0.6803 (0.0841)
# NN3    0.9819 (0.0056)   0.834 (0.0438)  0.7222 (0.1158)  0.6769 (0.0893)
# NN5    0.9821 (0.0034)  0.8618 (0.0616)  0.6926 (0.0765)  0.7334 (0.1252)
# RNN    0.9747 (0.0074)  0.5983 (0.0675)  0.7838 (0.1969)  0.1982 (0.1354)
# LSTM   0.9764 (0.0064)  0.6972 (0.0407)  0.6729 (0.1113)  0.4006 (0.0819)
#
#                F-score
# LR     0.6329 (0.0563)
# DT     0.6568 (0.0672)
# NB     0.0721 (0.0149)
# KNN    0.3737 (0.0906)
# RF      0.6484 (0.086)
# SVM    0.6403 (0.1197)
# BOOST  0.7184 (0.0592)
# NN1    0.7023 (0.0609)
# NN3     0.6911 (0.074)
# NN5    0.7035 (0.0612)
# RNN    0.3005 (0.1654)
# LSTM   0.4975 (0.0803)

# %% [markdown]
# #### Cross validation with 31000 unique visitors

# %%
# load cross validation metrics
cv_31k_lr = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_LR.pkl.gz')
cv_31k_dt = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_DT.pkl.gz')
cv_31k_nb = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_NB.pkl.gz')
cv_31k_knn = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_KNN.pkl.gz')
cv_31k_rf = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_RF.pkl.gz')
cv_31k_svm = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_SVM.pkl.gz')
cv_31k_boost = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_BOOST.pkl.gz')
cv_31k_nn1 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_NN1.pkl.gz')
cv_31k_nn3 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_NN3.pkl.gz')
cv_31k_nn5 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_NN5.pkl.gz')
cv_31k_rnn = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_RNN.pkl.gz')
cv_31k_lstm = pd.read_pickle('../results/cross_validation/cross_validation_metrics_25000_LSTM.pkl.gz')

# create dataframe with all models
cv_31k = cv_31k_lr
for df in [cv_31k_dt, cv_31k_nb, cv_31k_knn, cv_31k_rf, cv_31k_svm, cv_31k_boost, cv_31k_nn1, cv_31k_nn3, cv_31k_nn5, cv_31k_rnn, cv_31k_lstm]:
    cv_31k = cv_31k.append(df)
    
cv_31k[['Accuracy', 'AUC', 'Precision', 'Recall', 'F-score']]
# Out:
#               Accuracy              AUC        Precision           Recall  \
# LR      0.982 (0.0018)  0.8136 (0.0242)  0.7413 (0.0551)   0.6341 (0.049)
# DT     0.9795 (0.0024)  0.8403 (0.0271)   0.655 (0.0399)    0.692 (0.055)
# NB     0.8829 (0.0292)  0.8957 (0.0178)  0.2013 (0.0439)  0.9093 (0.0289)
# KNN    0.9773 (0.0034)  0.7165 (0.0206)  0.7037 (0.0388)  0.4387 (0.0413)
# RF     0.9857 (0.0017)  0.8263 (0.0171)   0.8363 (0.046)  0.6566 (0.0339)
# SVM    0.9832 (0.0032)  0.8339 (0.0244)   0.7558 (0.076)  0.6748 (0.0494)
# BOOST  0.9867 (0.0027)  0.8665 (0.0173)  0.8087 (0.0471)  0.7384 (0.0335)
# NN1    0.9855 (0.0017)  0.8477 (0.0327)  0.8032 (0.0449)    0.701 (0.067)
# NN3     0.9858 (0.002)  0.8409 (0.0335)  0.8212 (0.0523)  0.6865 (0.0684)
# NN5    0.9858 (0.0023)   0.8699 (0.027)  0.7775 (0.0496)  0.7465 (0.0542)
# RNN    0.9801 (0.0037)  0.7961 (0.0443)  0.7181 (0.0697)  0.6002 (0.0918)
# LSTM   0.9839 (0.0016)  0.8663 (0.0251)   0.734 (0.0539)    0.741 (0.052)
#
#                F-score
# LR     0.6814 (0.0335)
# DT     0.6713 (0.0316)
# NB     0.3275 (0.0595)
# KNN     0.539 (0.0319)
# RF     0.7351 (0.0321)
# SVM     0.7103 (0.044)
# BOOST  0.7716 (0.0364)
# NN1    0.7455 (0.0309)
# NN3     0.7443 (0.031)
# NN5    0.7603 (0.0406)
# RNN    0.6453 (0.0392)
# LSTM   0.7347 (0.0237)

# %% [markdown]
# #### Cross validation with 125000 unique visitors

# %%
# load cross validation metrics
cv_125k_lr = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_LR.pkl.gz')
cv_125k_dt = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_DT.pkl.gz')
cv_125k_nb = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_NB.pkl.gz')
cv_125k_knn = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_KNN.pkl.gz')
cv_125k_rf = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_RF.pkl.gz')
cv_125k_svm = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_SVM.pkl.gz')
cv_125k_boost = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_BOOST.pkl.gz')
cv_125k_nn1 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_NN1.pkl.gz')
cv_125k_nn3 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_NN3.pkl.gz')
cv_125k_nn5 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_NN5.pkl.gz')
cv_125k_rnn = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_RNN.pkl.gz')
cv_125k_lstm = pd.read_pickle('../results/cross_validation/cross_validation_metrics_100000_LSTM.pkl.gz')

# create dataframe with all models
cv_125k = cv_125k_lr
for df in [cv_125k_dt, cv_125k_nb, cv_125k_knn, cv_125k_rf, cv_125k_svm, cv_125k_boost, cv_125k_nn1, cv_125k_nn3, cv_125k_nn5, cv_125k_rnn, cv_125k_lstm]:
    cv_125k = cv_125k.append(df)
    
cv_125k[['Accuracy', 'AUC', 'Precision', 'Recall', 'F-score']]
# Out:
#               Accuracy              AUC        Precision           Recall  \
# LR     0.9834 (0.0015)  0.8237 (0.0137)   0.7809 (0.021)  0.6533 (0.0273)
# DT       0.98 (0.0017)  0.8467 (0.0156)   0.6704 (0.027)  0.7045 (0.0309)
# NB     0.9296 (0.0057)  0.9032 (0.0061)   0.292 (0.0264)  0.8749 (0.0118)
# KNN     0.9791 (0.002)  0.7438 (0.0177)  0.7525 (0.0222)  0.4928 (0.0355)
# RF     0.9862 (0.0011)  0.8435 (0.0076)  0.8382 (0.0294)  0.6913 (0.0152)
# SVM     0.984 (0.0021)  0.8438 (0.0157)  0.7719 (0.0414)  0.6943 (0.0312)
# BOOST  0.9874 (0.0013)   0.878 (0.0119)  0.8221 (0.0151)  0.7613 (0.0236)
# NN1    0.9872 (0.0008)  0.8595 (0.0154)  0.8453 (0.0159)  0.7232 (0.0314)
# NN3    0.9872 (0.0014)  0.8673 (0.0143)  0.8325 (0.0176)  0.7393 (0.0286)
# NN5    0.9869 (0.0007)  0.8712 (0.0095)   0.8175 (0.016)  0.7477 (0.0193)
# RNN    0.9814 (0.0017)   0.802 (0.0244)  0.7518 (0.0557)  0.6106 (0.0498)
# LSTM   0.9854 (0.0015)  0.8392 (0.0209)  0.8213 (0.0394)  0.6832 (0.0428)
#
#                F-score
# LR     0.7111 (0.0191)
# DT     0.6869 (0.0264)
# NB     0.4373 (0.0299)
# KNN     0.595 (0.0293)
# RF     0.7575 (0.0157)
# SVM    0.7304 (0.0285)
# BOOST  0.7904 (0.0169)
# NN1     0.779 (0.0157)
# NN3    0.7829 (0.0197)
# NN5    0.7809 (0.0144)
# RNN    0.6712 (0.0303)
# LSTM   0.7442 (0.0196)

# %% [markdown]
# #### Cross validation with 500000 unique visitors

# %%
# load cross validation metrics
cv_500k_lr = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_LR.pkl.gz')
cv_500k_dt = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_DT.pkl.gz')
cv_500k_nb = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_NB.pkl.gz')
cv_500k_knn = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_KNN.pkl.gz')
cv_500k_rf = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_RF.pkl.gz')
cv_500k_svm = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_SVM.pkl.gz')
cv_500k_boost = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_BOOST.pkl.gz')
cv_500k_nn1 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_NN1.pkl.gz')
cv_500k_nn3 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_NN3.pkl.gz')
cv_500k_nn5 = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_NN5.pkl.gz')
cv_500k_rnn = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_RNN.pkl.gz')
cv_500k_lstm = pd.read_pickle('../results/cross_validation/cross_validation_metrics_400000_LSTM.pkl.gz')

# create dataframe with all models
cv_500k = cv_500k_lr
for df in [cv_500k_dt, cv_500k_nb, cv_500k_knn, cv_500k_rf, cv_500k_svm, cv_500k_boost, cv_500k_nn1, cv_500k_nn3, cv_500k_nn5, cv_500k_rnn, cv_500k_lstm]:
    cv_500k = cv_500k.append(df)
    
cv_500k[['Accuracy', 'AUC', 'Precision', 'Recall', 'F-score']]
# Out:
#               Accuracy              AUC        Precision           Recall  \
# LR     0.9837 (0.0008)   0.8284 (0.006)   0.7871 (0.011)  0.6627 (0.0119)
# DT     0.9807 (0.0004)  0.8544 (0.0054)   0.6847 (0.013)  0.7197 (0.0111)
# NB     0.9401 (0.0019)  0.9017 (0.0032)  0.3293 (0.0078)  0.8606 (0.0055)
# KNN    0.9822 (0.0005)  0.7859 (0.0047)  0.8071 (0.0094)  0.5763 (0.0095)
# RF     0.9866 (0.0004)  0.8514 (0.0061)  0.8452 (0.0081)  0.7069 (0.0122)
# SVM     0.9839 (0.001)  0.8441 (0.0061)   0.7756 (0.027)   0.6948 (0.013)
# BOOST  0.9873 (0.0007)  0.8803 (0.0048)  0.8209 (0.0137)   0.766 (0.0095)
# NN1     0.988 (0.0006)  0.8682 (0.0109)  0.8626 (0.0158)  0.7403 (0.0222)
# NN3    0.9879 (0.0004)   0.875 (0.0124)  0.8478 (0.0195)  0.7544 (0.0257)
# NN5    0.9878 (0.0006)  0.8703 (0.0144)  0.8517 (0.0125)  0.7449 (0.0294)
# RNN    0.6877 (0.4745)  0.7614 (0.1811)   0.7069 (0.043)  0.5301 (0.3674)
# LSTM   0.9849 (0.0004)   0.8814 (0.015)  0.7576 (0.0271)  0.7709 (0.0312)
#
#                F-score
# LR     0.7195 (0.0089)
# DT     0.7017 (0.0076)
# NB     0.4763 (0.0085)
# KNN    0.6724 (0.0066)
# RF     0.7699 (0.0083)
# SVM    0.7326 (0.0095)
# BOOST  0.7924 (0.0082)
# NN1      0.7965 (0.01)
# NN3    0.7978 (0.0063)
# NN5    0.7942 (0.0134)
# RNN    0.7292 (0.0132)
# LSTM   0.7633 (0.0081)

# %% [markdown]
# ### 6.6. Algorithmic Efficiency

# %%
# gather training and testing times from model performance dataframes
times = model_performance_4k[['Training time', 'Testing time']].rename(columns={'Training time' : 'Sample 1 training time', 'Testing time' : 'Sample 1 testing time'})
samples = [2, 3, 4, 5, 6, 7, 8, 9, 10]
model_performances = [model_performance_8k, 
                      model_performance_16k, 
                      model_performance_31k, 
                      model_performance_63k, 
                      model_performance_125k, 
                      model_performance_250k, 
                      model_performance_500k, 
                      model_performance_1000k, 
                      model_performance_2000k]
for sample,model_performance in zip(samples,model_performances):
    times = pd.concat([times, model_performance[['Training time', 'Testing time']].rename(columns={'Training time' : 'Sample '+str(sample)+' training time', 'Testing time' : 'Sample '+str(sample)+' testing time'})], axis=1, sort=False)

# create dataframes for training and testing times
index = ['Training set 1', 
         'Training set 2', 
         'Training set 3', 
         'Training set 4', 
         'Training set 5', 
         'Training set 6', 
         'Training set 7', 
         'Training set 8', 
         'Training set 9', 
         'Training set 10']
train_times = pd.DataFrame(index=index)
train_times['unique_visitors'] = [3125, 6250, 12500, 25000, 50000, 100000, 200000, 400000, 800000, 1600000]

index = ['Test set 1', 
         'Test set 2', 
         'Test set 3', 
         'Test set 4', 
         'Test set 5', 
         'Test set 6', 
         'Test set 7', 
         'Test set 8', 
         'Test set 9', 
         'Test set 10']
test_times = pd.DataFrame(index=index)
test_times['unique_visitors'] = [781, 1502, 3125, 6250, 12500, 25000, 50000, 100000, 200000, 400000]

# load training and testing times for all samples and models into respective dataframes
models = ['LR', 'DT', 'NB', 'KNN', 'RF', 'SVM', 'BOOST', 'NN1', 'NN3', 'NN5', 'RNN', 'LSTM']
for model in models:
    train_times[model] = [model_performance_4k.at[model,'Training time'], 
                       model_performance_8k.at[model,'Training time'], 
                       model_performance_16k.at[model,'Training time'], 
                       model_performance_31k.at[model,'Training time'], 
                       model_performance_63k.at[model,'Training time'], 
                       model_performance_125k.at[model,'Training time'], 
                       model_performance_250k.at[model,'Training time'], 
                       model_performance_500k.at[model,'Training time'], 
                       model_performance_1000k.at[model,'Training time'], 
                       model_performance_2000k.at[model,'Training time']]    
for model in models:
    test_times[model] = [model_performance_4k.at[model,'Testing time'], 
                       model_performance_8k.at[model,'Testing time'], 
                       model_performance_16k.at[model,'Testing time'], 
                       model_performance_31k.at[model,'Testing time'], 
                       model_performance_63k.at[model,'Testing time'], 
                       model_performance_125k.at[model,'Testing time'], 
                       model_performance_250k.at[model,'Testing time'], 
                       model_performance_500k.at[model,'Testing time'], 
                       model_performance_1000k.at[model,'Testing time'], 
                       model_performance_2000k.at[model,'Testing time']]

# some modifications for plotting
train_times['unique_visitors (thousands)'] = train_times['unique_visitors'].apply(lambda x: str(int(x/1000)))
test_times['unique_visitors (thousands)'] = test_times['unique_visitors'].apply(lambda x: str(int(x/1000)))
train_times.at['Training set 3', 'unique_visitors (thousands)'] = '13'
test_times.at['Test set 1', 'unique_visitors (thousands)'] = '0.8'
test_times.at['Test set 2', 'unique_visitors (thousands)'] = '1.6'
test_times.at['Test set 5', 'unique_visitors (thousands)'] = '13'

# %%
# training times for all models
train_times
# Out:
#                  unique_visitors   LR   DT  NB    KNN   RF   SVM  BOOST  NN1  \
# Training set 1              3125    0    0   0      0    0     0      1    1
# Training set 2              6250    0    0   0      0    0     1      2    2
# Training set 3             12500    0    0   0      0    0     5      7    4
# Training set 4             25000    1    1   0      2    0    13     15    7
# Training set 5             50000    3    2   0     11    2    32     33   13
# Training set 6            100000    6    6   0     36    4    70     68   31
# Training set 7            200000   13   16   1    115    9   167    152   54
# Training set 8            400000   30   34   3    560   25   308    333  120
# Training set 9            800000   66   79   5   4225   79   694    778  250
# Training set 10          1600000  197  211  10  16557  209  1445   1460  554
#
#                  NN3  NN5   RNN   LSTM unique_visitors (thousands)
# Training set 1     2    3    23     73                           3
# Training set 2     3    5    41    110                           6
# Training set 3     6    8    79    214                          13
# Training set 4    11   15   134    380                          25
# Training set 5    21   29   217    644                          50
# Training set 6    39   52   444   1059                         100
# Training set 7    76  110   841   2401                         200
# Training set 8   159  219  1790   4191                         400
# Training set 9   328  436  3174   8840                         800
# Training set 10  743  945  7081  20196                        1600

# %%
# Figure 4
plt.figure(figsize=(12,8))

plt.subplot(3,1,1)
plt.plot(train_times['unique_visitors (thousands)'], train_times['LR'],linewidth=2, marker='v', markersize=10)
plt.plot(train_times['unique_visitors (thousands)'], train_times['DT'],linewidth=2,marker='X', markersize=10)
plt.plot(train_times['unique_visitors (thousands)'], train_times['NB'],linewidth=2,marker='o', markersize=10)
plt.plot(train_times['unique_visitors (thousands)'], train_times['RF'],linewidth=2,marker='P', markersize=10)
#plt.title('Training times', fontsize=16)
plt.ylabel('Seconds', fontsize=16)
#plt.xlabel('Unique visitors in training set (thousands)', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.legend(title='Models', title_fontsize=12, fontsize=12)
plt.grid(True)

plt.subplot(3,1,2)
plt.plot(train_times['unique_visitors (thousands)'], train_times['SVM'],linewidth=2, marker='<', markersize=10)
plt.plot(train_times['unique_visitors (thousands)'], train_times['BOOST'],linewidth=2, marker='>', markersize=10)
plt.plot(train_times['unique_visitors (thousands)'], train_times['NN1'],linewidth=2, marker='s', markersize=10)
plt.plot(train_times['unique_visitors (thousands)'], train_times['NN3'],linewidth=2, marker='p', markersize=10)
plt.plot(train_times['unique_visitors (thousands)'], train_times['NN5'],linewidth=2, marker='*', markersize=10)
#plt.title('Training times', fontsize=16)
plt.ylabel('Seconds', fontsize=16)
#plt.xlabel('Unique visitors in training set (thousands)', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.legend(title='Models', title_fontsize=12, fontsize=12)
plt.grid(True)

plt.subplot(3,1,3)
plt.plot(train_times['unique_visitors (thousands)'], train_times['KNN'],linewidth=2, marker='v', markersize=10)
plt.plot(train_times['unique_visitors (thousands)'], train_times['RNN'],linewidth=2, marker='X', markersize=10)
plt.plot(train_times['unique_visitors (thousands)'], train_times['LSTM'],linewidth=2, marker='o', markersize=10)
#plt.title('Training times', fontsize=16)
plt.ylabel('Seconds', fontsize=16)
plt.xlabel('Unique visitors in training set (thousands)', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.legend(title='Models', title_fontsize=12, fontsize=12)
plt.grid(True)

plt.tight_layout()
plt.savefig('training_times.png')
plt.show()

# %%
# testing times for all models
test_times
# Out:
#              unique_visitors  LR  DT  NB    KNN  RF  SVM  BOOST  NN1  NN3  \
# Test set 1               781   0   0   0      1   0    0      0    0    0
# Test set 2              1502   0   0   0      5   0    0      0    0    0
# Test set 3              3125   0   0   0     28   0    0      0    0    0
# Test set 4              6250   0   0   0    103   0    0      0    0    0
# Test set 5             12500   0   0   0    378   0    0      0    0    0
# Test set 6             25000   0   0   0   1344   0    0      0    0    0
# Test set 7             50000   0   0   0   3844   0    0      0    1    1
# Test set 8            100000   0   0   0  12321   0    0      0    2    3
# Test set 9            200000   0   0   1  38568   1    0      2    5    5
# Test set 10           400000   0   1   2  31631   3    0      3   10   13
#
#              NN5  RNN  LSTM unique_visitors (thousands)
# Test set 1     0    1     1                         0.8
# Test set 2     0    1     2                         1.6
# Test set 3     0    3     4                           3
# Test set 4     0    5     9                           6
# Test set 5     0   11    19                          13
# Test set 6     1   25    43                          25
# Test set 7     2   50    87                          50
# Test set 8     4  114   186                         100
# Test set 9     9  273   469                         200
# Test set 10   21  393   781                         400

# %%
# Figure 5
plt.figure(figsize=(12,8))

plt.subplot(4,1,1)
plt.plot(test_times['unique_visitors (thousands)'], test_times['LR'],linewidth=2, marker='v', markersize=10)
plt.plot(test_times['unique_visitors (thousands)'], test_times['DT'],linewidth=2, marker='x', markersize=10)
plt.plot(test_times['unique_visitors (thousands)'], test_times['NB'],linewidth=2, marker='o', markersize=10)
plt.plot(test_times['unique_visitors (thousands)'], test_times['RF'],linewidth=2, marker='P', markersize=10)
plt.plot(test_times['unique_visitors (thousands)'], test_times['SVM'],linewidth=2, marker='<', markersize=10)
plt.plot(test_times['unique_visitors (thousands)'], test_times['BOOST'],linewidth=2, marker='>', markersize=10)
#plt.title('Testing times', fontsize=16)
plt.ylabel('Seconds', fontsize=16)
#plt.xlabel('Unique visitors in test set (thousands)', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.legend(title='Models', title_fontsize=12, fontsize=12, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.grid(True)

plt.subplot(4,1,2)
plt.plot(test_times['unique_visitors (thousands)'], test_times['NN1'],linewidth=2, marker='s', markersize=10)
plt.plot(test_times['unique_visitors (thousands)'], test_times['NN3'],linewidth=2, marker='p', markersize=10)
plt.plot(test_times['unique_visitors (thousands)'], test_times['NN5'],linewidth=2, marker='*', markersize=10)
#plt.title('Testing times', fontsize=16)
plt.ylabel('Seconds', fontsize=16)
#plt.xlabel('Unique visitors in test set (thousands)', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.legend(title='Models', title_fontsize=12, fontsize=12, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.grid(True)

plt.subplot(4,1,3)
plt.plot(test_times['unique_visitors (thousands)'], test_times['RNN'],marker='v', markersize=10)
plt.plot(test_times['unique_visitors (thousands)'], test_times['LSTM'],marker='X', markersize=10)
#plt.title('Testing times', fontsize=16)
plt.ylabel('Seconds', fontsize=16)
#plt.xlabel('Unique visitors in test set (thousands)', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.legend(title='Models', title_fontsize=12, fontsize=12)
plt.grid(True)

plt.subplot(4,1,4)
plt.plot(test_times['unique_visitors (thousands)'], test_times['KNN'],marker='o', markersize=10)
#plt.title('Testing times', fontsize=16)
plt.ylabel('Seconds', fontsize=16)
plt.xlabel('Unique visitors in test set (thousands)', fontsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='x', labelsize=16)
plt.legend(title='Models', title_fontsize=12, fontsize=12)
plt.grid(True)

plt.tight_layout()
plt.savefig('testing_times.png')
plt.show()

# %% [markdown]
# ## Appendix

# %%
# Table 7
model_abbreviations = pd.read_csv('table_1_appendix_model_abbreviations.csv', sep=';').set_index('Abbreviations')
model_abbreviations
# Out:
#                                                  Models
# Abbreviations
# BAG                                             Bagging
# BM             Bayesian method (incl. Bayesian network)
# BOOST                                          Boosting
# CM                                         Custom model
# DA                                Discriminant analysis
# DBN                                 Deep belief network
# DT                                        Decision tree
# ENN                           Extended nearest neighbor
# ENS                                            Ensemble
# GLM                            Generalized linear model
# KNN                                 k nearest neighbors
# LMNN                      Large margin nearest neighbor
# LR                                  Logistic regression
# MISC-M                                    Miscellaneous
# MM                    Markov model (incl. Markov chain)
# NB                                          Naive Bayes
# NN                                       Neural network
# REG                           Regression (incl. linear)
# RF                                        Random forest
# RL                                  Rule-based learning
# RNN                            Recurrent neural network
# SDA                          Stack denoised autoencoder
# STC                                            Stacking
# SVM                              Support vector machine

# %%
# Table 8
metric_groups = pd.read_csv('table_2_appendix_metric_groups.csv', sep=';').set_index('Metric groups')
metric_groups
# Out:
#                                                                                                             Descriptions
# Metric groups
# Accuracy                        Metrics related to accuracy, such as accuracy, error, AUC, precision, reall and F-score.
# Complexity                             Metrics capturing model complexity, e.g. the number of leaves in a decision tree.
# Cost                          Metrics related to classification cost, such as cost of misclassification and cost matrix.
# Miscellaneous                                         Other less frequently used metrics like cross-entropy and Cohen k.
# Qualitative                                 Metric capturing comphrehensibility of results and ease of use, for example.
# Rank                                     Metrics used to rank models, e.g. Friedman ranking and mean rank of error rate.
# Test           Statistical tests used to compare models, such as t-test, Wilcoxon test and Duncan's multiple range test.
# Time                                                                          Metrics like training and prediction time.

# %%
# Table 9
best_features = pd.read_pickle('../results/descriptives/best_features.pkl.gz')
best_features
# Out:
#                                                                            F-values  \
# Features
# cart_view_boolean_sum                                                  139,298.2051
# user_gender_first_female                                               137,220.1141
# cart_addition_boolean_sum                                              113,868.7672
# user_gender_first_male                                                  85,542.2805
# net_promoter_score_first_Unknown                                        72,214.0085
# user_age_36-45_first                                                    56,486.5146
# user_age_26-35_first                                                    45,626.9895
# page_view_boolean_sum                                                   42,805.1345
# visit_page_num_max                                                      38,690.9081
# user_age_46-55_first                                                    36,042.6317
# product_view_boolean_sum                                                26,028.0626
# user_age_14-25_first                                                    24,796.6652
# visit_duration_seconds                                                  22,874.2933
# cart_removal_boolean_sum                                                22,469.2529
# net_promoter_score_first_10                                             19,854.6134
# last_purchase_num_max                                                   19,774.5008
# user_age_56-65_first                                                    16,330.8687
# net_promoter_score_first_8                                              15,699.7299
# marketing_channel_first_Paid Search G. Shopping                          7,899.2662
# net_promoter_score_first_7                                               7,730.3923
# net_promoter_score_first_9                                               7,634.2026
# user_age_65_plus_first                                                   6,726.4179
# net_promoter_score_first_5                                               6,705.8387
# net_promoter_score_first_6                                               5,426.7076
# device_type_user_agent_first_reduced_desktop                             3,687.5914
# suggested_search_results_clicked_sum                                     3,290.8795
# marketing_channel_first_Paid Search Other                                2,744.6967
# campaign_view_boolean_sum                                                2,734.6419
# product_categories_first_level_1_Schoenheit & Gesundheit                 2,465.7384
# standard_search_started_sum                                              2,397.9616
# device_type_user_agent_first_reduced_smartphone                          2,054.8272
# device_operating_system_user_agent_first_reduced_Windows                 1,922.9261
# product_views_in_last_visit_2-5                                          1,815.8281
# device_brand_name_user_agent_first_reduced_Unknown                       1,762.1659
# standard_search_results_clicked_sum                                      1,453.8475
# purchase_in_last_30_days                                                 1,404.9873
# device_operating_system_user_agent_first_reduced_Mac                     1,353.0430
# product_categories_first_level_1_Unknown                                 1,351.0870
# daily_visitor_first                                                      1,324.8893
# weekly_visitor_first                                                     1,298.3265
# device_operating_system_user_agent_first_reduced_iOS                     1,263.1567
# net_promoter_score_first_3                                               1,251.4915
# monthly_visitor_first                                                    1,193.9328
# net_promoter_score_first_4                                               1,193.9158
# yearly_visitor_first                                                     1,172.6729
# quarterly_visitor_first                                                  1,169.5488
# purchase_in_last_30_plus_days                                            1,048.3661
# visit_in_last_24_hours                                                     990.9017
# product_views_in_last_visit_6-10                                           939.3123
# hit_of_logged_in_user_first                                                913.3604
# page_views_in_last_visit_11-20                                             904.4414
# page_views_in_last_visit_20_plus                                           844.8740
# may                                                                        798.0432
# marketing_channel_first_Social Media Prospecting                           742.3289
# registered_user_first                                                      729.7445
# product_items_sum                                                          680.0924
# device_browser_user_agent_first_reduced_Firefox                            600.6560
# referrer_type_first_internal                                               594.9086
# purchase_in_last_7_days                                                    581.1653
# page_views_in_last_visit_6-10                                              564.9381
# referrer_type_first_social_network                                         556.6437
# marketing_channel_first_Display Prospecting                                554.9200
# device_browser_user_agent_first_reduced_Facebook                           550.5770
# referrer_type_first_search_engine                                          540.2521
# search_engine_first_reduced_Unknown                                        540.2521
# device_browser_user_agent_first_reduced_Internet Explorer                  489.6883
# product_categories_first_level_1_Wohnen & Haushalt                         481.8430
# product_views_in_last_visit_11-20                                          474.5107
# net_promoter_score_first_2                                                 446.5033
# net_promoter_score_first_1                                                 393.1214
# device_brand_name_user_agent_first_reduced_Samsung                         389.1774
# referrer_type_first_external                                               351.8508
# product_views_in_last_visit_20_plus                                        287.7069
# product_categories_first_level_1_Mode & Accessoires                        242.1921
# device_brand_name_user_agent_first_reduced_Apple                           238.3461
# search_page_num_first                                                      237.7717
# night                                                                      215.3672
# product_categories_first_level_1_Baumarkt & Garten                         190.2410
# evening                                                                    185.1531
# august                                                                     181.2891
# page_views_in_last_visit_2-5                                               174.1737
# visit_in_last_7_days                                                       169.8574
# device_browser_user_agent_first_reduced_Microsoft Edge                     169.0213
# product_categories_first_level_1_Computer & Elektronik                     159.2840
# device_type_user_agent_first_reduced_tablet                                157.5823
# device_browser_user_agent_first_reduced_Safari                             154.0295
# purchase_in_last_24_hours                                                  139.2971
# product_views_in_last_visit_0                                              127.3281
# visit_during_tv_spot_first                                                 125.1221
# cookies_first                                                              120.1939
# Switzerland_first                                                          117.1452
# morning                                                                    110.3111
# afternoon                                                                  102.9941
# marketing_channel_first_Direct                                              94.3774
# visit_num                                                                   85.4637
# marketing_channel_first_Social Media Non-Paid                               79.4110
# product_categories_first_level_1_Sport & Freizeit                           77.6181
# persistent_cookie_first                                                     75.7754
# device_browser_user_agent_first_reduced_Samsung Browser                     65.5183
# marketing_channel_first_Unknown                                             62.8962
# hourly_visitor_first                                                        59.0399
# page_views_in_last_visit_1                                                  58.9725
# device_type_user_agent_first_reduced_phablet                                56.2352
# product_categories_first_level_1_Lebensmittel & Getraenke                   43.5593
# device_operating_system_user_agent_first_reduced_Windows Phone              39.2718
# july                                                                        38.8917
# marketing_channel_first_Social Media Campaigns                              35.5019
# marketing_channel_first_Referring Domains                                   35.1411
# device_brand_name_user_agent_first_reduced_Sony                             32.0423
# repeat_orders_first                                                         30.6992
# device_brand_name_user_agent_first_reduced_Nokia                            27.4495
# product_views_in_last_visit_1                                               25.8129
# june                                                                        25.6435
# device_brand_name_user_agent_first_reduced_Other                            25.5425
# connection_type_first_Mobile Carrier                                        23.9268
# weekday                                                                     21.4913
# weekend                                                                     21.4913
# device_brand_name_user_agent_first_reduced_Huawei                           18.1476
# device_brand_name_user_agent_first_reduced_HTC                              16.2417
# device_type_user_agent_first_reduced_portable media player                  14.6949
# search_engine_first_reduced_Microsoft                                       14.0107
# marketing_channel_first_Paid Search Brand                                   13.6271
# visit_in_last_30_plus_days                                                  13.5832
# product_item_price_sum                                                      13.0656
# october                                                                     12.9397
# search_engine_first_reduced_Yahoo!                                          12.7671
# device_brand_name_user_agent_first_reduced_Microsoft                        12.5035
# device_brand_name_user_agent_first_reduced_Google                           11.7961
# september                                                                   10.8032
# visit_in_last_30_days                                                       10.0541
# device_brand_name_user_agent_first_reduced_Wiko                              8.5434
# device_brand_name_user_agent_first_reduced_Lenovo                            7.9891
# device_brand_name_user_agent_first_reduced_Motorola                          7.7613
# device_brand_name_user_agent_first_reduced_LG                                7.0339
# page_views_in_last_visit_0                                                   6.4080
# device_browser_user_agent_first_reduced_Chrome                               5.8322
# marketing_channel_first_Social Media Remarketing                             5.4663
# middle_of_month                                                              4.3210
# device_type_user_agent_first_reduced_Unknown                                 3.7599
# device_brand_name_user_agent_first_reduced_OnePlus                           3.3408
# beginning_of_month                                                           3.2844
# marketing_channel_first_Mail Other                                           2.7042
# device_operating_system_user_agent_first_reduced_Unknown                     2.1994
# device_brand_name_user_agent_first_reduced_Toshiba                           2.1609
# referrer_type_first_nojs                                                     2.0329
# device_operating_system_user_agent_first_reduced_Ubuntu                      1.8954
# new_visit_first                                                              1.6032
# device_brand_name_user_agent_first_reduced_RIM                               1.5677
# marketing_channel_first_Editorial                                            1.2814
# device_browser_user_agent_first_reduced_Other                                0.8961
# marketing_channel_first_Other Campaign                                       0.6283
# marketing_channel_first_Display Remarketing                                  0.4788
# device_browser_user_agent_first_reduced_Opera                                0.3342
# device_brand_name_user_agent_first_reduced_Asus                              0.3290
# marketing_channel_first_Organic Search                                       0.2826
# search_engine_first_reduced_Other                                            0.2728
# end_of_month                                                                 0.1175
# connection_type_first_Modem                                                  0.0652
# device_operating_system_user_agent_first_reduced_Other                       0.0514
# cart_value_sum                                                               0.0435
# marketing_channel_first_Mail Flaschenpost                                    0.0361
# marketing_channel_first_Other - unidentified                                 0.0326
# device_operating_system_user_agent_first_reduced_GNU/Linux                   0.0210
# product_categories_first_level_1_Medien & Unterhaltung                       0.0169
# device_operating_system_user_agent_first_reduced_Chrome OS                   0.0117
# marketing_channel_first_Digital Documents                                    0.0102
#
#                                                                            p-values
# Features
# cart_view_boolean_sum                                                        0.0000
# user_gender_first_female                                                     0.0000
# cart_addition_boolean_sum                                                    0.0000
# user_gender_first_male                                                       0.0000
# net_promoter_score_first_Unknown                                             0.0000
# user_age_36-45_first                                                         0.0000
# user_age_26-35_first                                                         0.0000
# page_view_boolean_sum                                                        0.0000
# visit_page_num_max                                                           0.0000
# user_age_46-55_first                                                         0.0000
# product_view_boolean_sum                                                     0.0000
# user_age_14-25_first                                                         0.0000
# visit_duration_seconds                                                       0.0000
# cart_removal_boolean_sum                                                     0.0000
# net_promoter_score_first_10                                                  0.0000
# last_purchase_num_max                                                        0.0000
# user_age_56-65_first                                                         0.0000
# net_promoter_score_first_8                                                   0.0000
# marketing_channel_first_Paid Search G. Shopping                              0.0000
# net_promoter_score_first_7                                                   0.0000
# net_promoter_score_first_9                                                   0.0000
# user_age_65_plus_first                                                       0.0000
# net_promoter_score_first_5                                                   0.0000
# net_promoter_score_first_6                                                   0.0000
# device_type_user_agent_first_reduced_desktop                                 0.0000
# suggested_search_results_clicked_sum                                         0.0000
# marketing_channel_first_Paid Search Other                                    0.0000
# campaign_view_boolean_sum                                                    0.0000
# product_categories_first_level_1_Schoenheit & Gesundheit                     0.0000
# standard_search_started_sum                                                  0.0000
# device_type_user_agent_first_reduced_smartphone                              0.0000
# device_operating_system_user_agent_first_reduced_Windows                     0.0000
# product_views_in_last_visit_2-5                                              0.0000
# device_brand_name_user_agent_first_reduced_Unknown                           0.0000
# standard_search_results_clicked_sum                                          0.0000
# purchase_in_last_30_days                                                     0.0000
# device_operating_system_user_agent_first_reduced_Mac                         0.0000
# product_categories_first_level_1_Unknown                                     0.0000
# daily_visitor_first                                                          0.0000
# weekly_visitor_first                                                         0.0000
# device_operating_system_user_agent_first_reduced_iOS                         0.0000
# net_promoter_score_first_3                                                   0.0000
# monthly_visitor_first                                                        0.0000
# net_promoter_score_first_4                                                   0.0000
# yearly_visitor_first                                                         0.0000
# quarterly_visitor_first                                                      0.0000
# purchase_in_last_30_plus_days                                                0.0000
# visit_in_last_24_hours                                                       0.0000
# product_views_in_last_visit_6-10                                             0.0000
# hit_of_logged_in_user_first                                                  0.0000
# page_views_in_last_visit_11-20                                               0.0000
# page_views_in_last_visit_20_plus                                             0.0000
# may                                                                          0.0000
# marketing_channel_first_Social Media Prospecting                             0.0000
# registered_user_first                                                        0.0000
# product_items_sum                                                            0.0000
# device_browser_user_agent_first_reduced_Firefox                              0.0000
# referrer_type_first_internal                                                 0.0000
# purchase_in_last_7_days                                                      0.0000
# page_views_in_last_visit_6-10                                                0.0000
# referrer_type_first_social_network                                           0.0000
# marketing_channel_first_Display Prospecting                                  0.0000
# device_browser_user_agent_first_reduced_Facebook                             0.0000
# referrer_type_first_search_engine                                            0.0000
# search_engine_first_reduced_Unknown                                          0.0000
# device_browser_user_agent_first_reduced_Internet Explorer                    0.0000
# product_categories_first_level_1_Wohnen & Haushalt                           0.0000
# product_views_in_last_visit_11-20                                            0.0000
# net_promoter_score_first_2                                                   0.0000
# net_promoter_score_first_1                                                   0.0000
# device_brand_name_user_agent_first_reduced_Samsung                           0.0000
# referrer_type_first_external                                                 0.0000
# product_views_in_last_visit_20_plus                                          0.0000
# product_categories_first_level_1_Mode & Accessoires                          0.0000
# device_brand_name_user_agent_first_reduced_Apple                             0.0000
# search_page_num_first                                                        0.0000
# night                                                                        0.0000
# product_categories_first_level_1_Baumarkt & Garten                           0.0000
# evening                                                                      0.0000
# august                                                                       0.0000
# page_views_in_last_visit_2-5                                                 0.0000
# visit_in_last_7_days                                                         0.0000
# device_browser_user_agent_first_reduced_Microsoft Edge                       0.0000
# product_categories_first_level_1_Computer & Elektronik                       0.0000
# device_type_user_agent_first_reduced_tablet                                  0.0000
# device_browser_user_agent_first_reduced_Safari                               0.0000
# purchase_in_last_24_hours                                                    0.0000
# product_views_in_last_visit_0                                                0.0000
# visit_during_tv_spot_first                                                   0.0000
# cookies_first                                                                0.0000
# Switzerland_first                                                            0.0000
# morning                                                                      0.0000
# afternoon                                                                    0.0000
# marketing_channel_first_Direct                                               0.0000
# visit_num                                                                    0.0000
# marketing_channel_first_Social Media Non-Paid                                0.0000
# product_categories_first_level_1_Sport & Freizeit                            0.0000
# persistent_cookie_first                                                      0.0000
# device_browser_user_agent_first_reduced_Samsung Browser                      0.0000
# marketing_channel_first_Unknown                                              0.0000
# hourly_visitor_first                                                         0.0000
# page_views_in_last_visit_1                                                   0.0000
# device_type_user_agent_first_reduced_phablet                                 0.0000
# product_categories_first_level_1_Lebensmittel & Getraenke                    0.0000
# device_operating_system_user_agent_first_reduced_Windows Phone               0.0000
# july                                                                         0.0000
# marketing_channel_first_Social Media Campaigns                               0.0000
# marketing_channel_first_Referring Domains                                    0.0000
# device_brand_name_user_agent_first_reduced_Sony                              0.0000
# repeat_orders_first                                                          0.0000
# device_brand_name_user_agent_first_reduced_Nokia                             0.0000
# product_views_in_last_visit_1                                                0.0000
# june                                                                         0.0000
# device_brand_name_user_agent_first_reduced_Other                             0.0000
# connection_type_first_Mobile Carrier                                         0.0000
# weekday                                                                      0.0000
# weekend                                                                      0.0000
# device_brand_name_user_agent_first_reduced_Huawei                            0.0000
# device_brand_name_user_agent_first_reduced_HTC                               0.0001
# device_type_user_agent_first_reduced_portable media player                   0.0001
# search_engine_first_reduced_Microsoft                                        0.0002
# marketing_channel_first_Paid Search Brand                                    0.0002
# visit_in_last_30_plus_days                                                   0.0002
# product_item_price_sum                                                       0.0003
# october                                                                      0.0003
# search_engine_first_reduced_Yahoo!                                           0.0004
# device_brand_name_user_agent_first_reduced_Microsoft                         0.0004
# device_brand_name_user_agent_first_reduced_Google                            0.0006
# september                                                                    0.0010
# visit_in_last_30_days                                                        0.0015
# device_brand_name_user_agent_first_reduced_Wiko                              0.0035
# device_brand_name_user_agent_first_reduced_Lenovo                            0.0047
# device_brand_name_user_agent_first_reduced_Motorola                          0.0053
# device_brand_name_user_agent_first_reduced_LG                                0.0080
# page_views_in_last_visit_0                                                   0.0114
# device_browser_user_agent_first_reduced_Chrome                               0.0157
# marketing_channel_first_Social Media Remarketing                             0.0194
# middle_of_month                                                              0.0376
# device_type_user_agent_first_reduced_Unknown                                 0.0525
# device_brand_name_user_agent_first_reduced_OnePlus                           0.0676
# beginning_of_month                                                           0.0699
# marketing_channel_first_Mail Other                                           0.1001
# device_operating_system_user_agent_first_reduced_Unknown                     0.1381
# device_brand_name_user_agent_first_reduced_Toshiba                           0.1416
# referrer_type_first_nojs                                                     0.1539
# device_operating_system_user_agent_first_reduced_Ubuntu                      0.1686
# new_visit_first                                                              0.2055
# device_brand_name_user_agent_first_reduced_RIM                               0.2105
# marketing_channel_first_Editorial                                            0.2576
# device_browser_user_agent_first_reduced_Other                                0.3438
# marketing_channel_first_Other Campaign                                       0.4280
# marketing_channel_first_Display Remarketing                                  0.4890
# device_browser_user_agent_first_reduced_Opera                                0.5632
# device_brand_name_user_agent_first_reduced_Asus                              0.5662
# marketing_channel_first_Organic Search                                       0.5950
# search_engine_first_reduced_Other                                            0.6014
# end_of_month                                                                 0.7317
# connection_type_first_Modem                                                  0.7985
# device_operating_system_user_agent_first_reduced_Other                       0.8206
# cart_value_sum                                                               0.8349
# marketing_channel_first_Mail Flaschenpost                                    0.8493
# marketing_channel_first_Other - unidentified                                 0.8568
# device_operating_system_user_agent_first_reduced_GNU/Linux                   0.8848
# product_categories_first_level_1_Medien & Unterhaltung                       0.8966
# device_operating_system_user_agent_first_reduced_Chrome OS                   0.9138
# marketing_channel_first_Digital Documents                                    0.9197
